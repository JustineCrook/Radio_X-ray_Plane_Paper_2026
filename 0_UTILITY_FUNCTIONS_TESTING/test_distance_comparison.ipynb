# %%
import sys
import pandas as pd
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from galdist_lmxb import *

# %%
# 1A 1744-361
RA, DEC = get_deg('17h48m13.07s', '-36d07m57.5s')
d_eval_min = 5.8
d_eval_max = 13
plot_PDF(RA, DEC, d_eval_min=d_eval_min, d_eval_max=d_eval_max, zoom=False)
plot_PDF(RA, DEC, d_eval_min=d_eval_min, d_eval_max=d_eval_max, zoom=True)
# Out:
# RA in degrees: 267.05445833333334
# Dec in degrees: -36.13263888888889
# EVAL_DIST at max PDF: 8.023302330233022
# 0.9999999994667721
#
# Probability of distance > 5.8 kpc: 0.9532
# Probability of distance < 13 kpc: 0.9511
# EVAL_DIST at max PDF: 8.023302330233022
# 0.9999999994667721
#
# Probability of distance > 5.8 kpc: 0.9532
# Probability of distance < 13 kpc: 0.9511

# %%
# 4U 1543–47
RA, DEC = 236.784, -47.67
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 7.580758075807581

# %%
# 4U 1630–47
RA, DEC = 248.506, -47.394
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 9.800980098009802

# %%
# Centaurus X–4
RA, DEC = get_deg('14h58m21.9347842080s', '-31d40m07.515432768s')
#RA, DEC = 224.541, -31.673
plot_PDF(RA, DEC)
# Out:
# RA in degrees: 224.59139493419997
# Dec in degrees: -31.668754286880002
# EVAL_DIST at max PDF: 8.210821082108211

# %%
# Circinus X–1
RA, DEC = 230.17, -57.167
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 10.561056105610561

# %%
# EXO 1846
RA, DEC = get_deg('18h49m17.047s', '-03d03m55.24s')
plot_PDF(RA, DEC)
# Out:
# RA in degrees: 282.3210291666666
# Dec in degrees: -3.0653444444444444
# EVAL_DIST at max PDF: 9.700970097009701

# %%
# GRS 1739–278
RA, DEC = 265.661,-27.748
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 8.000800080008002

# %%
# GRS 1915+105
RA, DEC = 	288.798,10.946
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 10.371037103710371

# %%
# GX 339
# 17 h 02 49 .38 and Dec = −48 • 47 ′ 23 ′′ .2
RA, DEC = get_deg('17h02m49.38s', '-48d47m23.2s')
plot_PDF(RA, DEC)
# Out:
# RA in degrees: 255.70575
# Dec in degrees: -48.78977777777778
# EVAL_DIST at max PDF: 7.920792079207922

# %%
# H1743–322
RA, DEC = 266.565, -32.234
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 8.010801080108012

# %%
# IGR J17091–3624
RA, DEC = 257.281,-36.413
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 8.080808080808081

# %%
# MAXI J1348–630
RA, DEC = 207.053, 	-63.275
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 9.43094309430943

# %%
# MAXI J1631-479
RA, DEC = get_deg('16h31m14.22s', '-47d48m23.44s')
plot_PDF(RA, DEC)
plot_PDF(RA, DEC, 0, 20)
# Out:
# RA in degrees: 247.80924999999996
# Dec in degrees: -47.80651111111111
# EVAL_DIST at max PDF: 9.810981098109812
# EVAL_DIST at max PDF: 9.812981298129813

# %%
# MAXI J1803–298
RA, DEC = 270.762,-29.83
plot_PDF(RA, DEC)
plot_PDF(RA, DEC, d_eval_min=5, d_eval_max=15, zoom=True)
# Out:
# EVAL_DIST at max PDF: 8.012901290129012
# 0.9999999996944062
#
# Probability of distance > 6 kpc: 0.9656
# Probability of distance < 17 kpc: 0.9903
# EVAL_DIST at max PDF: 8.012901290129012
# 0.9999999996944062
#
# Probability of distance > 5 kpc: 0.9851
# Probability of distance < 15 kpc: 0.9811

# %%
# MAXI J1807+132
RA, DEC = 	272.032,13.248
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 4.340434043404341

# %%
# MAXI J1810–222
RA, DEC = 273.165,-22.323
plot_PDF(RA, DEC)
plot_PDF(RA, DEC, d_eval_min=10, d_eval_max=16)
# Out:
# EVAL_DIST at max PDF: 8.067506750675069
# 0.9999999994328268
#
# Probability of distance > 6 kpc: 0.9438
# Probability of distance < 17 kpc: 0.9508
# EVAL_DIST at max PDF: 8.067506750675069
# 0.9999999994328268
#
# Probability of distance > 10 kpc: 0.3027
# Probability of distance < 16 kpc: 0.9350

# %%
# MAXI J1816–195
RA, DEC = 274.218,-19.633
plot_PDF(RA, DEC)
plot_PDF(RA, DEC, d_eval_min=1, d_eval_max=8.7, zoom=True)
plot_PDF(RA, DEC, d_eval_min=5, d_eval_max=8.7, zoom=True)
# Out:
# EVAL_DIST at max PDF: 8.111711171117111
# 0.9999999992626093
#
# Probability of distance > 6 kpc: 0.9346
# Probability of distance < 17 kpc: 0.9229
# EVAL_DIST at max PDF: 8.111711171117111
# 0.9999999992626093
#
# Probability of distance > 1 kpc: 1.0000
# Probability of distance < 8.7 kpc: 0.4250
# EVAL_DIST at max PDF: 8.111711171117111
# 0.9999999992626093
#
# Probability of distance > 5 kpc: 0.9698
# Probability of distance < 8.7 kpc: 0.4250

# %%
# MAXI J1820
RA, DEC = get_deg('18h20m22s', '+07d11m07s')
plot_PDF(RA, DEC)
# Out:
# RA in degrees: 275.0916666666666
# Dec in degrees: 7.185277777777778
# EVAL_DIST at max PDF: 5.990599059905991

# %%
# SAX J1808.4–3658
RA, DEC = 272.054,-36.912
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 7.940794079407941
# 0.9999999999993895
#
# Probability of distance > 6 kpc: 0.9099
# Probability of distance < 17 kpc: 0.9911

# %%
# SAX J1810.8-2609
RA, DEC = get_deg('18h10m44s', '26d09m01s')
plot_PDF(RA, DEC)
# Out:
# RA in degrees: 272.6833333333333
# Dec in degrees: 26.150277777777777
# EVAL_DIST at max PDF: 2.9102910291029103

# %%
# Swift J1727.8–1613
RA, DEC = 261.942,-16.214
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 7.800780078007802
# 0.9999999999984384
#
# Probability of distance > 6 kpc: 0.8538
# Probability of distance < 17 kpc: 0.9813

# %%
# Swift J1728.9–3613
RA, DEC = 262.252,-36.242
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 8.080808080808081
# 0.9999999999999092
#
# Probability of distance > 6 kpc: 0.9545
# Probability of distance < 17 kpc: 0.9157

# %%
# Swift J1842.5–1124
RA, DEC = 280.573,	-11.418
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 8.130813081308132
# 0.9999999999994738
#
# Probability of distance > 6 kpc: 0.8667
# Probability of distance < 17 kpc: 0.9362

# %%
# Swift J1858.6–0814
RA, DEC = 284.645,-8.237
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 7.670767076707671
# 0.9999999999986098
#
# Probability of distance > 6 kpc: 0.7850
# Probability of distance < 17 kpc: 0.9631

# %%
# XTE J1701–462
RA, DEC = 255.242,-46.189
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 8.190819081908192
# 0.9999999999996458
#
# Probability of distance > 6 kpc: 0.8920
# Probability of distance < 17 kpc: 0.9217

# %%
# Vela X–1
RA, DEC = 	134.71,	-41.413
plot_PDF(RA, DEC)
# Out:
# EVAL_DIST at max PDF: 6.350635063506351
# 0.9999999999967579
#
# Probability of distance > 6 kpc: 0.6857
# Probability of distance < 17 kpc: 0.9371
