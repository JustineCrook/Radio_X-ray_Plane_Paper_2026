# %% [markdown]
# This source is not used for the LrLx analysis.

# %%
import sys
import pandas as pd
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from get_data import *
from plotting import *
from get_LrLx_data import *

# %% [markdown]
# # Get Data

# %%
source_df, obs_df, radio_df, xray_df = read_data("../DATA/Swift J1858.6-0814.txt")
# Out:
# Swift J1858.6-0814
# Added 5% systematic uncertainty to the radio data.
# Warning for row(s): [1] -- Fx, Fx_unc_l, or Fx_unc_u is empty for this detection.
# X-ray uncertainty percentage:  nan
# Warning: The X-ray statistical uncertainty confidence interval should be 68 percent or 90 percent... Assuming it is 68 percent.
# Added 10.0% systematic uncertainty to the X-ray data.

# %%
radio_df.head()
# Out:
#                  name     blockID band      t_radio  dt_radio  Rphase Rstate     Fr    Fr_unc            local_rms  alpha  alpha_unc  Fr_uplim_bool
# 0  Swift J1858.6-0814  1541845876    L  58432.51021  0.010417     NaN     HS  0.126  0.016731  2018-11-10 12:14:42    NaN        NaN          False
# 1  Swift J1858.6-0814  1542451956    L  58439.49621  0.010417     NaN     HS  0.084  0.009544  2018-11-17 11:54:33    NaN        NaN          False
# 2  Swift J1858.6-0814  1543053930    L  58446.46321  0.010417     NaN     HS  0.114  0.009929  2018-11-24 11:07:01    NaN        NaN          False
# 3  Swift J1858.6-0814  1543743065    L  58454.43921  0.010417     NaN     HS  0.132  0.009708  2018-12-02 10:32:28    NaN        NaN          False
# 4  Swift J1858.6-0814  1544259897    L  58460.42121  0.010417     NaN     HS  0.126  0.013025  2018-12-08 10:06:33    NaN        NaN          False

# %% [markdown]
# # Light Curves

# %%
# WITH systematic error
plot_radio_lightcurve(radio_df)
