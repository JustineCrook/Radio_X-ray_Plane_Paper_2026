# %% [markdown]
# I do not use this one for the LrLx plane.

# %%
import sys
import pandas as pd
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from get_data import *
from plotting import *
from get_LrLx_data import *

# %% [markdown]
# # Get Data

# %%
source_df, obs_df, radio_df, xray_df = read_data("../DATA/Swift J1728.9-3613.txt")
# Out:
# Swift J1728.9-3613
# Added 5% systematic uncertainty to the radio data.
# Warning for row(s): [1] -- Fx, Fx_unc_l, or Fx_unc_u is empty for this detection.
# X-ray uncertainty percentage:  68
# Added 10.0% systematic uncertainty to the X-ray data.

# %%
radio_df.head()
# Out:
#                  name     blockID band      t_radio  dt_radio  Rphase Rstate       Fr    Fr_unc   local_rms  alpha  alpha_unc  Fr_uplim_bool
# 0  Swift J1728.9-3613  1548901878    L  58514.11610  0.010366     NaN    IMS  10.9000  0.551702   99.196736    NaN        NaN          False
# 1  Swift J1728.9-3613  1549937193    L  58526.11058  0.031098     NaN    IMS   0.2703  0.090100   90.090160    NaN        NaN           True
# 2  Swift J1728.9-3613  1550284172    L  58530.15573  0.010366     NaN    IMS   0.3397  0.113233  113.236844    NaN        NaN           True
# 3  Swift J1728.9-3613  1550886965    L  58537.13310  0.010273     NaN     SS   1.8920  0.114722   66.958050    NaN        NaN          False
# 4  Swift J1728.9-3613  1551404170    L  58543.11739  0.010366     NaN     SS   1.9870  0.126509   80.638465    NaN        NaN          False

# %% [markdown]
# # Light Curves

# %%
# WITH systematic error
plot_radio_lightcurve(radio_df)
