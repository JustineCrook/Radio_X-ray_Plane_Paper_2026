# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data, BHs

# %% [markdown]
# ### One run using the best distance estimates

# %%
run_linmix(N_runs=1, interp=True, type_source="BH", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00207054 1.01487946 1.01816197 1.00435733 1.00699388 1.02813553]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99832875 1.00440858 1.02856938 0.99912317 1.01302763 1.01714812]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0038555  0.99967347 1.0100937  1.00441984 1.01031161 1.00960066]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00592945 0.99905762 1.00843741 0.99890779 1.01210512 1.00929202]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00130463 0.99851544 1.00775272 0.99938126 1.0093526  1.00390938]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00456292 1.00046624 1.00410721 0.99964049 1.00531709 1.00211666]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0016518  0.99899191 1.00347116 0.99972469 1.00528595 1.00344078]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00206059 0.99944547 1.00430191 0.99964881 1.00491246 1.00260679]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00210221 0.99915374 1.00392673 0.99987279 1.00044145 1.00184816]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00240896 0.99972173 1.00364312 1.0006872  1.00024053 1.00133296]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00200439 1.00023054 1.00390299 1.00010672 1.00061773 1.00180766]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00310085 1.00066345 1.00597445 0.99985697 1.00126048 1.0032809 ]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00366285 1.00153285 1.00558928 0.99954858 1.00145203 1.00321016]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00278354 1.00070818 1.00345479 0.9996803  1.00139175 1.00281854]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0021846  1.00001917 1.00288138 0.99993354 1.00127224 1.00253221]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00113125 0.99975024 1.00315836 0.99991843 1.00049992 1.00079738]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00063248 0.99963078 1.00295229 0.99985835 1.00046904 1.00115543]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048418 0.99981696 1.00271185 0.99994022 1.00042863 1.00103952]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035611 0.99988897 1.00161642 1.00013823 1.00040572 1.00076054]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032616 0.99963416 1.00063277 1.00020585 1.00037136 1.00081475]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012081 0.99955376 1.00071504 1.00023802 1.00032041 1.00133295]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992022 0.99955046 1.00055527 1.00006005 1.00030411 1.00124194]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991463 0.99960732 1.00067275 1.00000453 1.00028964 1.00091395]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99977835 0.99962121 1.00039859 1.00004586 1.00027815 1.00076178]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999833 0.99972656 1.00054854 1.0000552  1.0002672  1.00064184]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014392 0.99979612 1.00087646 1.0000418  1.00025724 1.00078544]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017408 0.99981119 1.00061235 1.00006147 1.00024945 1.00072049]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00026591 0.99991013 1.00080273 1.00000572 1.00024159 1.00085536]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00002301 1.00012707 1.00069029 0.9999464  1.00023348 1.00081711]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989121 1.00016178 1.00028259 0.99999925 1.00022489 1.00064758]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988721 1.00010459 1.00036787 0.9998696  1.00021801 1.00060164]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000094 1.00016726 1.00033969 0.99985607 1.00044299 1.00052211]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000322 1.00015333 1.00026531 0.9998655  1.00043651 1.00060739]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990572 1.00007142 1.00010354 0.99991474 1.00042511 1.00059131]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984521 1.00013843 0.99997053 0.99996602 1.00041576 1.00050598]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991606 1.00015814 1.00006474 0.99997544 1.00006963 1.00054613]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004157 1.00002421 1.00013436 0.99992656 1.00006752 1.00052655]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006156 1.00000648 1.00013079 0.99987617 1.00006547 1.00043182]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006161 0.9999259  0.99995932 0.99995013 1.00008072 1.00052373]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010063 1.00000811 0.99997757 0.99997117 1.00007799 1.00055481]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001372 1.00002786 0.99994617 0.99989148 1.00007585 1.00054257]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996921 1.00004071 0.99988505 0.99991062 1.00017    1.00062017]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005812 1.00015924 0.99982999 0.99994207 1.00016601 1.00065202]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001153  1.00024853 0.99982434 0.99994133 1.00016193 1.00063689]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021235 1.00030386 0.99984798 0.99994861 1.00015852 1.00061129]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035059 1.00051706 0.99987051 0.99988214 1.0001549  1.00062396]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034657 1.00051404 0.99985259 0.99990521 1.00015129 1.00059406]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035755 1.00036812 0.99983271 0.99993697 1.00014816 1.00057861]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00047424 1.00027357 0.99985181 0.99990872 1.00014454 1.00044651]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00052907 1.00014467 0.99987573 0.99992011 1.00014121 1.00039602]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= True, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.143  -0.034  +0.035
# Beta  = 0.582  -0.026  +0.026
# Sigma = 0.484  -0.026  +0.025
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.143  -0.033  +0.035
# Beta  = 0.582  -0.025  +0.026
# Sigma = 0.483  -0.024  +0.026
# The 90% lower limit on beta from all values
# Beta > 0.550
# The 90% upper limit on beta from all values
# Beta < 0.615
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.143  -0.033  +0.035
# Beta =  0.582  -0.025  +0.026
# Sigma =  0.483  -0.024  +0.026
# The 90% lower limit on beta from run results
# Beta >  0.55
# The 90% upper limit on beta from run results
# Beta <  0.62

# %% [markdown]
# ### 100 runs

# %%
run_linmix(N_runs=100, interp=True, type_source="BH", K=3, seed=5, parallel=True, verbose=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_100
# 100%|██████████| 100/100 [04:51<00:00,  2.92s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.148  -0.043  +0.043
# Beta  = 0.579  -0.028  +0.028
# Sigma = 0.473  -0.032  +0.032
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.149  -0.044  +0.043
# Beta  = 0.579  -0.028  +0.029
# Sigma = 0.472  -0.031  +0.033
# The 90% lower limit on beta from all values
# Beta > 0.543
# The 90% upper limit on beta from all values
# Beta < 0.616
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.148  -0.033  +0.033
# Beta =  0.579  -0.024  +0.025
# Sigma =  0.472  -0.023  +0.026
# The 90% lower limit on beta from run results
# Beta >  0.55
# The 90% upper limit on beta from run results
# Beta <  0.61

# %% [markdown]
# # 1000 Runs

# %%
run_linmix(N_runs=1000, interp=True, type_source="BH", K=3, seed=5, parallel=True, verbose=True)

# %%
linmix_results(N_runs=1000, interp= True, type_source="BH")

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data BHs

# %% [markdown]
# # One Run

# %%
run_linmix(N_runs=1, interp=False, type_source="BH", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['4U 1543-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070' 'Swift J1727.8-1613']
# Number of source: 12
# DIRECTORY:  ./MCMC_parfiles_paired_BH_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03193299 1.0372589  1.02156491 0.99714315 1.01571488 1.01390899]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00687146 1.00311668 1.00941038 0.9990674  1.00766056 1.0007218 ]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99961351 1.00063961 1.00360914 1.00106177 1.00309902 0.99931415]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99879161 1.00309748 0.99978146 0.99934952 1.00263868 0.99963886]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99809465 1.00008842 1.00036791 1.00140618 1.00195421 1.00023999]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99851235 1.00025952 1.00214751 1.00120647 1.00175417 1.00023213]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99881178 0.99991123 1.00060403 1.00053448 1.00026567 0.99941448]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006041 0.99966066 1.0018351  1.00068171 1.00040892 0.9992187 ]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00065031 0.99940141 1.0008894  1.0003054  1.0016711  0.99984418]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00132578 0.99912618 1.00044221 1.00066269 1.00135487 0.99971521]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00197282 0.9996158  1.00191721 0.99975394 1.00120682 0.9995495 ]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00169624 0.99961184 1.00075872 0.99969569 1.00111386 0.99967435]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00112658 0.99955319 1.00007481 0.99977173 1.0010343  0.99990666]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045291 0.99992468 0.99996663 1.00012574 1.00094893 0.99987323]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00054333 0.99994085 0.99982985 1.0006597  1.0008072  0.99998734]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024469 1.00022065 0.99991895 1.00010912 1.00076927 1.00000649]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0003387  1.0000544  1.00048136 0.99973962 1.0007545  1.00007721]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030209 1.00026788 1.00045684 0.99985276 1.00080348 1.00035694]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00022288 1.00001331 1.00009643 0.99984744 1.0001583  1.00047794]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983109 0.99975307 0.99987588 0.99980437 1.00017492 1.00051804]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010684 0.9996663  0.99990935 0.99981185 1.00016746 1.00042669]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000162   0.99965862 0.99997753 0.99986043 1.00017791 1.00058955]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00002873 0.99974368 0.99987588 0.99982144 1.00028586 1.00041597]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990088 0.99998203 0.99997457 0.99982479 1.00027748 1.00053002]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998796  0.99986833 1.00010732 0.99994171 1.00025793 1.00042125]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.999843   0.99988071 1.00013391 0.99982462 1.00002333 1.00024318]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986331 0.99966492 1.00017677 0.99983016 1.00002293 1.00042861]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995054 0.99969446 1.0004485  0.99980827 1.00002081 1.00063838]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998979  0.99975364 1.00057274 0.99982388 1.00001988 1.00058316]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99994087 0.99974383 1.00073178 0.99988003 1.00002309 1.00058439]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995879 0.99999318 1.00062504 0.99982393 0.99995312 1.00017996]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985587 0.99986951 1.00038252 0.99981709 0.99995466 1.00023377]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979046 1.00000046 1.00027706 0.99972506 0.99995564 1.00023677]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989479 1.0000372  1.00049838 0.99972039 0.99995744 1.00032109]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981335 1.0001653  1.00034559 0.99973878 0.99992544 1.00030909]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984977 1.00004444 1.00033823 0.99974825 0.99992777 1.00031273]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986367 1.00010089 1.00038943 0.99973582 0.99992936 1.00032677]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985856 1.00034376 1.00036038 0.99975333 1.00018682 1.00037104]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985177 1.00054259 1.00040995 0.99978674 1.00018565 1.00060223]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986582 1.00045563 1.00053823 0.9997854  1.00018068 1.00066316]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984468 1.00035019 1.00055178 0.9997906  1.00017534 1.00069886]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998206  1.00040524 1.00039547 0.99980238 1.00017028 1.00079197]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985308 1.00093641 1.00030709 0.99979484 1.0001662  1.00077917]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995766 1.00079317 1.00030652 0.9998019  1.0001622  1.00071436]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999433  1.00064811 1.00036744 0.99980463 1.00015832 1.00062438]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993832 1.00091242 1.00033683 0.99981298 1.00015467 1.00070051]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989923 1.00082017 1.00029297 0.99981718 1.00015156 1.00064933]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992045 1.00063592 1.00034764 0.99980329 1.00014985 1.0006899 ]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990248 1.00062499 1.00038494 0.99980405 1.00014569 1.00069654]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990513 1.00058305 1.00026646 0.99982472 1.00014259 1.0006989 ]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= False, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_BH_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['4U 1543-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070' 'Swift J1727.8-1613']
# Number of source: 12
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.153  -0.039  +0.038
# Beta  = 0.580  -0.028  +0.028
# Sigma = 0.455  -0.030  +0.029
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.153  -0.038  +0.039
# Beta  = 0.580  -0.028  +0.028
# Sigma = 0.454  -0.028  +0.031
# The 90% lower limit on beta from all values
# Beta > 0.544
# The 90% upper limit on beta from all values
# Beta < 0.616
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.153  -0.038  +0.039
# Beta =  0.580  -0.028  +0.028
# Sigma =  0.454  -0.028  +0.031
# The 90% lower limit on beta from run results
# Beta >  0.54
# The 90% upper limit on beta from run results
# Beta <  0.62

# %% [markdown]
# ---

# %% [markdown]
# ###
