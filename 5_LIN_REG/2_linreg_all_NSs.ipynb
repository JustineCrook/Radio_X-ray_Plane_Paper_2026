# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data NSs

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, min_iter=10000)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04419932 1.11273434 1.0338533  0.99576035 0.99460324 1.01485541]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04810146 1.0190319  1.05236651 1.00009471 1.0004216  1.00498433]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04025099 1.00613917 1.04927197 0.99805104 0.99991796 1.0118396 ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0525948  1.00894292 1.06776884 1.0093554  0.99966239 1.01711367]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04274551 1.0403596  1.08691784 1.00953095 0.99981303 1.0073856 ]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03598436 1.02794586 1.07395431 1.00758258 0.9996214  1.01727489]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01183127 1.02020698 1.02578389 1.01281509 0.99966182 1.02211108]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00776799 1.04402857 1.0146958  1.0081044  0.99968398 1.03222813]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00334532 1.06220479 1.00490689 1.00440552 0.99984516 1.0232965 ]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00557035 1.07708455 1.00497482 1.00792117 0.99984298 1.02448749]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0037825  1.04840887 1.00171888 1.00967421 0.99991989 1.01387491]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00111544 1.03598244 1.0007462  1.00816937 0.99997398 1.0127727 ]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00125091 1.03127177 1.00196594 1.00747089 1.00000023 1.01472589]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00191524 1.0405652  1.00114908 1.00962516 0.99986202 1.01495527]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00265684 1.05024216 1.00111328 1.01061986 0.99979763 1.01768053]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00232612 1.05396498 1.0003845  1.00969178 0.999803   1.01847566]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00109741 1.05468929 0.9998202  1.00741484 0.99985142 1.01822774]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058406 1.04550826 0.99983054 1.00397012 0.99999594 1.01257702]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00199663 1.03957358 1.00117727 1.00306644 0.99999644 1.01200112]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0033833  1.03013691 1.001889   1.0032977  0.99999728 1.00733686]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00471379 1.03129215 1.00219722 1.00176957 0.9999971  1.00816863]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00624696 1.02503733 1.00242862 1.00194526 0.99999691 1.00534031]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0075496  1.02552691 1.00312592 1.00208539 0.99999705 1.00569782]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00657644 1.02440296 1.0025448  1.00235787 0.9999972  1.0050723 ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00835275 1.02543329 1.00364862 1.00254385 0.99999719 1.00556274]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00680034 1.0214582  1.00352581 1.00143512 0.99994604 1.00263096]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00705632 1.02046802 1.00508949 1.00100127 0.99994828 1.00231774]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00440169 1.02276526 1.003261   1.00094026 0.99994984 1.00217465]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0042365  1.02195516 1.00389928 1.00158455 0.99995165 1.00205589]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00336796 1.02112652 1.00349947 1.00151307 0.99995322 1.00173651]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00232699 1.0216029  1.00293393 1.0014162  0.99995475 1.00189166]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00183986 1.02280817 1.00253367 1.00148179 0.99995641 1.00213047]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00110447 1.0228923  1.00170121 1.00166982 0.999958   1.00241305]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00065934 1.02276584 1.00139876 1.0016001  0.99995937 1.00256538]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00063914 1.02317684 1.00158939 1.00183072 0.99996351 1.00286138]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00066941 1.02352696 1.00180431 1.00144988 0.99996438 1.00296148]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013043 1.02193305 1.00111056 1.00097805 0.99996536 1.00319747]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997236 1.01920731 1.00102469 1.00072184 0.99996474 1.00254993]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99994555 1.02067511 1.00088264 1.00063583 0.99996143 1.00307824]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982331 1.01988308 1.00052169 1.00068362 0.99996267 1.00311499]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979528 1.01953232 1.00037652 1.00070303 0.99996275 1.00413102]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983014 1.02048416 1.00048561 1.00082756 0.9999636  1.00453755]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008563 1.02204873 1.00087693 1.00089327 0.99996343 1.00416231]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00026479 1.02100707 1.00151368 1.00078456 0.99996398 1.00352046]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023761 1.0206236  1.00135055 1.00066419 0.99996472 1.00349734]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046778 1.02179346 1.00186445 1.00076477 0.99996549 1.00436951]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00111625 1.02188418 1.002832   1.00084164 0.99996625 1.00502996]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139699 1.02016343 1.00322335 1.00090541 0.9999669  1.00497808]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00195311 1.02145661 1.004705   1.00086071 0.99996751 1.00458765]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00258756 1.02098395 1.00569086 1.00123642 0.9999681  1.00406816]
#
# Iteration:  5100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00272426 1.02097376 1.00587131 1.00114395 0.9999687  1.00471106]
#
# Iteration:  5200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00239792 1.02230291 1.0053158  1.00094072 0.99996719 1.00515728]
#
# Iteration:  5300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00204032 1.02325785 1.00513789 1.00096328 0.99996785 1.00542625]
#
# Iteration:  5400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00161633 1.02630408 1.00422498 1.00094172 0.99996809 1.00592588]
#
# Iteration:  5500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0020438  1.02759575 1.00495957 1.00107632 0.99996798 1.00680445]
#
# Iteration:  5600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00245816 1.0283589  1.0057095  1.00108593 0.99996854 1.0072723 ]
#
# Iteration:  5700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00270136 1.02918235 1.00627765 1.0010982  0.99996919 1.00705998]
#
# Iteration:  5800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00246195 1.02898086 1.00577397 1.0007806  0.99996969 1.00694874]
#
# Iteration:  5900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00274569 1.02748627 1.00635671 1.00095537 0.99997022 1.00572131]
#
# Iteration:  6000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00317601 1.027611   1.0070321  1.00086979 0.99997055 1.00567122]
#
# Iteration:  6100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00347212 1.02674817 1.0076488  1.0009874  0.99997024 1.00552504]
#
# Iteration:  6200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0041911  1.0293087  1.0086755  1.00114188 0.99997067 1.00583465]
#
# Iteration:  6300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0047433  1.03096229 1.00952915 1.00101789 0.99997111 1.00555094]
#
# Iteration:  6400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00466079 1.03215576 1.00956441 1.00091865 0.99997154 1.005912  ]
#
# Iteration:  6500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00407341 1.03052258 1.00863624 1.00086838 0.999972   1.00574067]
#
# Iteration:  6600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00425321 1.02900302 1.0084693  1.0008094  0.99997253 1.00600106]
#
# Iteration:  6700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00488023 1.0294491  1.00927757 1.00082569 0.99997292 1.00612648]
#
# Iteration:  6800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00573663 1.02873421 1.0104401  1.0009291  0.99997335 1.00599816]
#
# Iteration:  6900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0060013  1.02860824 1.01104625 1.00087657 0.99997354 1.00562109]
#
# Iteration:  7000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00684435 1.02862641 1.0126156  1.00097522 0.99997393 1.00493812]
#
# Iteration:  7100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00770703 1.02769932 1.01350783 1.00089609 0.99997428 1.00457537]
#
# Iteration:  7200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00826361 1.02633157 1.01401303 1.0008718  0.99997454 1.00383766]
#
# Iteration:  7300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0088975  1.02557796 1.01447712 1.00095775 0.99997488 1.00346962]
#
# Iteration:  7400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00845062 1.02416931 1.01430403 1.00083354 0.99997519 1.00329981]
#
# Iteration:  7500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0086185  1.02237204 1.01436709 1.00072509 0.99997549 1.00285793]
#
# Iteration:  7600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00994399 1.02148391 1.0159261  1.00052246 0.99997575 1.00262789]
#
# Iteration:  7700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01104912 1.02189248 1.01714307 1.00047078 0.99997605 1.00276731]
#
# Iteration:  7800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01180965 1.0226002  1.0177774  1.00058045 0.99997634 1.0023714 ]
#
# Iteration:  7900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01168524 1.02371814 1.01784861 1.0005268  0.99997656 1.00215103]
#
# Iteration:  8000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01210949 1.02401829 1.01840569 1.00057002 0.99997684 1.00222277]
#
# Iteration:  8100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01304208 1.0245682  1.01897213 1.0003843  0.9999772  1.00203934]
#
# Iteration:  8200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01333183 1.02386009 1.01944737 1.00028813 0.99997758 1.00210272]
#
# Iteration:  8300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01275416 1.0235501  1.0190764  1.00031299 0.9999778  1.00220142]
#
# Iteration:  8400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01226014 1.02261448 1.01865622 1.00029025 0.99997804 1.00221586]
#
# Iteration:  8500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0118832  1.02219386 1.01763924 1.00023656 0.99997819 1.00237457]
#
# Iteration:  8600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0119096  1.02129933 1.01762911 1.00015414 0.99997852 1.00203135]
#
# Iteration:  8700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01216721 1.021412   1.01819349 1.0002416  0.99997876 1.00183134]
#
# Iteration:  8800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01158846 1.01914984 1.01747861 1.00016686 0.9999791  1.00155685]
#
# Iteration:  8900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01058266 1.01787311 1.01643195 1.00011352 0.99997938 1.00155533]
#
# Iteration:  9000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00960652 1.01701444 1.01514124 1.00007075 0.99997959 1.00155988]
#
# Iteration:  9100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00870624 1.01599954 1.0140897  1.00003105 0.99997981 1.00146511]
#
# Iteration:  9200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00839172 1.01601002 1.01344401 1.00001494 0.99997999 1.00164959]
#
# Iteration:  9300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00796071 1.0162683  1.01284645 1.00010727 0.99998026 1.00184149]
#
# Iteration:  9400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00819938 1.01707671 1.01344354 1.00008074 0.9999805  1.0017986 ]
#
# Iteration:  9500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00799274 1.01627403 1.01327148 1.00012091 0.99998067 1.00183936]
#
# Iteration:  9600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00784177 1.01638593 1.0129312  1.00012912 0.99998089 1.00192535]
#
# Iteration:  9700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00803282 1.01647121 1.01327051 1.00008001 0.99998113 1.0017986 ]
#
# Iteration:  9800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00839932 1.01665466 1.01366111 1.00002738 0.99997924 1.00174164]
#
# Iteration:  9900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00913034 1.01741909 1.0146435  1.00006057 0.99997921 1.0018841 ]
#
# Iteration:  10000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00917322 1.01768251 1.0148267  1.00000613 0.99997939 1.00184974]
# Length of chain: 20000

# %%
linmix_results(N_runs=1, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.646  -0.918  +0.813
# Beta  = 0.769  -0.372  +0.402
# Sigma = 1.756  -0.765  +0.835
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -2.421  -1.144  +0.588
# Beta  = 0.759  -0.361  +0.412
# Sigma = 1.576  -0.585  +1.015
# The 90% lower limit on beta from all values
# Beta > 0.272
# The 90% upper limit on beta from all values
# Beta < 1.308
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -2.421  -1.144  +0.588
# Beta =  0.759  -0.361  +0.412
# Sigma =  1.576  -0.585  +1.015
# The 90% lower limit on beta from run results
# Beta >  0.27
# The 90% upper limit on beta from run results
# Beta <  1.31

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# 100%|██████████| 100/100 [02:19<00:00,  1.39s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.347  -0.660  +0.663
# Beta  = 0.831  -0.405  +0.401
# Sigma = 1.480  -0.648  +0.653
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -2.158  -0.849  +0.474
# Beta  = 0.757  -0.331  +0.474
# Sigma = 1.293  -0.460  +0.840
# The 90% lower limit on beta from all values
# Beta > 0.331
# The 90% upper limit on beta from all values
# Beta < 1.423
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -2.190  -0.851  +0.480
# Beta =  0.772  -0.323  +0.469
# Sigma =  1.330  -0.459  +0.825
# The 90% lower limit on beta from run results
# Beta >  0.36
# The 90% upper limit on beta from run results
# Beta <  1.42

# %% [markdown]
# ### 1000 Runs

# %%
run_linmix(N_runs=1000, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True)

# %%
linmix_results(N_runs=1000, interp= True, type_source="NS")

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data NS

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=False, type_source="NS", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_paired_NS_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01912901 1.00352261 1.03847647 1.01678258 0.99849386 1.00045371]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03878767 1.08994998 1.03860658 1.00576829 1.01178878 1.03605954]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06597542 1.10542139 1.08084365 1.02249313 1.01416464 1.0715752 ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04099912 1.0636557  1.0479889  1.0109819  1.00252478 1.04813423]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03405752 1.04462074 1.02731794 1.00067463 1.00282454 1.03559349]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05129905 1.07510778 1.04622536 1.00115724 0.99987302 1.05624266]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04547267 1.11947691 1.04780669 1.00262901 0.99975792 1.05256848]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06931331 1.09843248 1.06720751 1.00119974 0.99986308 1.04516154]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06773148 1.10346979 1.07013904 1.00327231 0.99987495 1.05143693]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07181657 1.13434165 1.05909518 1.00342698 1.00011554 1.04513653]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05555092 1.17568759 1.03923689 1.00198024 1.00014356 1.04410911]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03815167 1.20919227 1.02578473 0.9999515  0.99987055 1.05520929]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01744415 1.24288184 1.01476932 1.00165129 0.9998818  1.07451186]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01979306 1.27188418 1.01356242 1.00163599 1.00062224 1.0935235 ]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02770628 1.2849067  1.02117861 1.00028384 1.00008144 1.11023638]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03201617 1.29916192 1.02935401 0.9998652  1.00007657 1.13223307]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02983044 1.2720676  1.03537461 0.99978722 1.00007053 1.13561095]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02883263 1.22082088 1.03950126 0.99969066 1.00006345 1.12855983]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02913765 1.19036122 1.04388133 0.99987292 1.00005734 1.12691277]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02663876 1.17572479 1.04308826 1.00033711 1.00005329 1.12579448]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02123754 1.16658106 1.03516216 1.00053052 1.0000507  1.12010111]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02055129 1.16489985 1.03556298 1.00013481 1.00001196 1.12375936]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02180542 1.16635842 1.03573965 1.00038452 1.00035853 1.12327908]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02574026 1.16578619 1.0362852  1.00108333 1.00030947 1.1183914 ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03161468 1.1699691  1.03745266 1.00108694 1.00027729 1.11495092]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03765748 1.16929412 1.04035797 1.00102686 1.00003748 1.10630674]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04366718 1.16403456 1.04188066 1.00120106 1.00003358 1.09376239]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04693162 1.15502067 1.04246501 1.00123724 1.00029263 1.08549444]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05460735 1.1500927  1.04723054 1.00120545 1.00028096 1.08115389]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06557937 1.1365756  1.05604451 1.00115323 1.00027525 1.07691766]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07228137 1.12851878 1.05846018 1.00066945 1.00026736 1.07251124]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07383931 1.12626008 1.05927321 1.00038013 1.00025985 1.07208948]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07295644 1.12679346 1.05885302 1.00042803 1.00025171 1.06899587]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07523105 1.12406142 1.06306499 1.00057429 1.00024406 1.06679934]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07866399 1.12524427 1.06508105 1.00049129 1.00017259 1.06560594]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.08211792 1.12446484 1.06779696 1.0001414  1.00016164 1.06435661]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.08315114 1.11451866 1.06846492 0.99992835 1.00015721 1.06171319]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.08132825 1.10715856 1.06868699 0.99987081 1.00015171 1.06191829]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07960141 1.1005018  1.06577733 0.99989053 1.00014771 1.06029749]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0769541  1.09146445 1.06110169 0.99999628 1.00014389 1.05656572]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07312879 1.08432274 1.05662308 1.00007121 1.00013952 1.05528739]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07290603 1.07397966 1.0546668  1.00022422 1.00013625 1.05127921]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07405775 1.06258227 1.05737697 1.0001691  1.00013297 1.04731009]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07309533 1.05493456 1.05910824 1.00024354 1.00012999 1.04341317]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07318836 1.05246883 1.06017726 1.00032668 1.00012773 1.0414804 ]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0748196  1.05240243 1.06136689 1.00060659 1.00012239 1.0388185 ]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0752336  1.05093284 1.0635579  1.00073437 1.00011969 1.03692455]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07602837 1.04802697 1.06297439 1.00058502 1.00011709 1.03435445]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07573687 1.04647425 1.06214714 1.00046903 1.00011453 1.03251961]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07397424 1.04543831 1.06069623 1.00058765 1.0001114  1.03109923]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= False, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -3.433  -1.284  +1.267
# Beta  = 1.261  -0.675  +0.719
# Sigma = 2.352  -1.178  +1.193
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -3.262  -1.456  +1.096
# Beta  = 1.195  -0.609  +0.785
# Sigma = 2.188  -1.014  +1.357
# The 90% lower limit on beta from all values
# Beta > 0.441
# The 90% upper limit on beta from all values
# Beta < 2.212
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -3.262  -1.456  +1.096
# Beta =  1.195  -0.609  +0.785
# Sigma =  2.188  -1.014  +1.357
# The 90% lower limit on beta from run results
# Beta >  0.44
# The 90% upper limit on beta from run results
# Beta <  2.21

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data NSs, No Upper Limits

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, include_Fr_uplims=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99689346 1.00324822 1.01554074 0.99664574 1.00018251 1.00383897]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99602989 1.00634115 1.01148302 1.02076584 0.99914097 1.00335698]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00110418 0.99903354 0.99819401 1.01790657 0.99941289 1.00009414]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990335 0.99788461 1.00277573 1.02176096 0.99957895 1.00471415]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00136704 0.99819793 1.00416177 1.01154722 0.99964047 1.00266759]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00168597 0.99902282 1.01002938 1.00611834 0.99969143 1.0057034 ]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00074118 0.99919011 1.00842387 1.00590808 0.9997364  1.00274946]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00137765 1.00000395 1.00496831 1.00403298 0.99983891 1.00222495]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00147805 0.99979563 1.00349251 1.00337244 0.99985623 1.00229698]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00127564 0.99943481 1.00245295 1.00199956 0.99987117 1.0021847 ]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00169621 0.99923264 1.00160014 1.00075335 0.99988429 1.00181525]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00125331 0.99921114 1.00135134 1.0010912  0.99981685 1.00026428]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00104155 0.9993461  1.00277607 1.00122294 1.00011155 1.00025625]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00056264 0.99948184 1.00285634 1.00087246 1.00011297 1.00038511]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00081116 0.99948004 1.0019113  1.00146189 1.00010798 1.00002036]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00072733 0.99949981 1.00162328 1.0007797  1.00010201 0.99977362]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00051257 0.99968695 1.00129093 1.00089382 1.00009628 0.99972284]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030438 0.99982589 1.00110159 1.00095162 1.00009293 0.99946555]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00029354 0.99964257 1.00100101 1.00174969 0.99972255 0.99961381]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0004413  0.99969182 1.00138457 1.00118464 0.9997365  0.99966352]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00042954 0.99978138 1.00182279 1.00091702 0.99974708 0.99980432]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00043042 0.99975974 1.00188886 1.00101379 1.00006905 0.99975927]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00044166 0.99975387 1.00172469 1.00039357 1.00006692 0.9998537 ]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024145 0.99973661 1.00120303 1.0004695  1.00006572 0.99987014]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000464 0.9996808  1.00084072 1.00053911 1.00005931 0.99985659]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997042 0.99968188 1.00086602 1.00061348 1.00005675 0.99991242]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993303 0.99968703 1.0004396  1.00098996 1.00003261 0.99972509]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00002064 0.99968213 1.0004734  1.00117805 1.00001604 0.99967916]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997575 0.99967287 1.00035225 1.00101625 1.00002153 0.99970072]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006192 0.99967292 1.00042241 1.00063984 1.00001954 0.99969474]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999906  0.99974073 1.00043786 1.00097692 1.00002079 0.9997275 ]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000166 0.99975393 1.00050093 1.00101409 1.00001656 0.99976798]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995067 0.99971371 1.00043132 1.00089142 1.00001538 0.99979196]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999558  0.9997411  1.00025792 1.00073539 1.00001481 0.99984816]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991395 0.99976573 1.00034432 1.00072437 1.00002073 0.99985419]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990222 0.99975918 1.00019867 1.00073567 1.00002064 0.99990129]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999315  0.99974359 1.00009808 1.00079147 0.99999436 0.99980739]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993288 0.99975579 1.0000935  1.00064733 1.00000771 0.99978126]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990741 0.99975148 0.99999616 1.00034082 1.00000639 0.99977922]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989767 0.99975663 1.00006124 1.00027367 1.00000593 0.99979603]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989618 0.99975727 1.0001961  1.00040877 1.00000246 0.99978309]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988524 0.99978243 1.00033697 1.00040194 1.00000269 0.99984837]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998927  0.99980152 1.00018474 1.00029865 1.00000506 0.99986389]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991599 0.99982712 1.00022287 1.00027067 1.00000495 0.99984296]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995033 0.99984998 1.00028355 1.00030464 1.0000048  0.99986313]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999323  0.99988119 1.00028325 1.00020055 1.00000467 0.99994158]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001855 0.99991003 1.00024747 1.0001328  1.00000456 0.99989455]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001679 0.99999273 1.00041229 1.00006807 1.00000446 0.99988565]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998482 1.00005797 1.00039922 1.00006324 1.00000437 0.99992183]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995033 1.0000724  1.00034931 1.0002165  1.00000429 0.99996945]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.786  -0.243  +0.237
# Beta  = 0.692  -0.265  +0.264
# Sigma = 0.719  -0.336  +0.273
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.785  -0.245  +0.236
# Beta  = 0.694  -0.267  +0.262
# Sigma = 0.584  -0.201  +0.409
# The 90% lower limit on beta from all values
# Beta > 0.320
# The 90% upper limit on beta from all values
# Beta < 1.056
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.785  -0.245  +0.236
# Beta =  0.694  -0.267  +0.262
# Sigma =  0.584  -0.201  +0.409
# The 90% lower limit on beta from run results
# Beta >  0.32
# The 90% upper limit on beta from run results
# Beta <  1.06

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, interp=True, type_source="NS", K=3, seed=5, parallel=True, include_Fr_uplims=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]

# %%
linmix_results(N_runs=100, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.804  -0.240  +0.241
# Beta  = 0.624  -0.303  +0.294
# Sigma = 0.678  -0.329  +0.273
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.803  -0.241  +0.240
# Beta  = 0.634  -0.313  +0.284
# Sigma = 0.550  -0.202  +0.401
# The 90% lower limit on beta from all values
# Beta > 0.210
# The 90% upper limit on beta from all values
# Beta < 1.021
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.799  -0.235  +0.224
# Beta =  0.627  -0.273  +0.265
# Sigma =  0.550  -0.191  +0.390
# The 90% lower limit on beta from run results
# Beta >  0.25
# The 90% upper limit on beta from run results
# Beta <  0.99
