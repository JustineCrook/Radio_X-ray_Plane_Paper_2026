# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data NSs

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, min_iter=5000, max_iter=20000)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=20000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02801408 1.00078304 1.03025911 1.01240748 1.00830702 0.99936307]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05553024 1.07511063 1.09655268 1.00312407 1.00020595 1.01380033]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.13709162 1.07365779 1.18421468 0.99922982 0.99998201 1.02986636]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.17680691 1.10262023 1.2022995  1.0010415  0.99999118 1.03767998]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.12746571 1.08860936 1.15096947 1.00048693 0.99999234 1.02056062]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.1123163  1.05617362 1.13072387 1.00361278 0.99999346 1.01778284]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07447023 1.06330004 1.1049985  1.00456945 0.99999354 1.008548  ]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05931793 1.06650733 1.0929565  1.00502638 0.99997409 1.00396427]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06818774 1.05368844 1.09889578 1.00420014 0.99997714 1.00908904]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0721855  1.05548726 1.10286738 1.00467914 1.00000808 1.00910659]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06694355 1.050344   1.09627219 1.00580149 1.00000711 1.00857127]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03856124 1.03651847 1.06606786 1.00529637 1.00004254 1.00691828]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0232546  1.04272664 1.0432654  1.00465013 1.00003913 1.0033708 ]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01763401 1.04278232 1.03282119 1.00423133 1.00003623 1.00202555]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01646814 1.04798644 1.02809148 1.00440884 1.00003414 1.0026678 ]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01306301 1.03067688 1.02213957 1.00355491 1.00003216 1.00282619]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0101585  1.02856842 1.0133891  1.00419131 1.00002907 1.00315911]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00482132 1.01446913 1.00685568 1.00268809 1.00002756 1.00255381]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00296756 1.00602885 1.00342374 1.00229496 1.00002487 1.00199704]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00093696 1.00775319 1.00175527 1.00274159 1.00002332 0.99998625]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979563 1.01003516 1.00150931 1.00240774 1.00003113 1.00004415]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996552 1.01055399 1.00241659 1.00232673 1.00002974 0.99975998]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996552 1.00954423 1.00249268 1.00174738 1.00002848 0.99973663]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00066076 1.00895634 1.00165599 1.00137543 1.00002718 0.99984844]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00206967 1.0098017  1.00265603 1.00137999 1.00002613 0.99988784]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00360155 1.01347272 1.00521524 1.0011109  1.00002498 0.99994727]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00358077 1.01513737 1.00600571 1.00086363 1.00002398 1.00012931]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00485493 1.01517601 1.00735884 1.00090689 1.00002316 1.00010347]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00418173 1.01548829 1.00647508 1.00069535 1.00002233 0.99985179]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00389538 1.01552547 1.00580679 1.00049778 1.00002159 0.99998903]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00235378 1.01047089 1.00406235 1.00049185 1.00002133 0.99995862]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00213794 1.0096199  1.00422459 1.00027445 1.0000207  1.00001089]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00209448 1.01040614 1.00535481 1.0007404  1.00002149 1.0005216 ]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00286257 1.01015015 1.00559106 1.00069113 1.00002083 1.00048691]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00236491 1.00737803 1.00496276 1.00092467 1.00002461 1.00086244]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00202547 1.00599553 1.00473233 1.00055565 1.00002405 1.00085491]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00198269 1.00421693 1.00428321 1.00054628 1.00002342 1.00083084]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00191473 1.00272285 1.00542533 1.00059335 1.00002279 1.00141902]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00064171 1.00236884 1.00306615 1.00060366 1.0000222  1.00054746]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002991  1.00265049 1.00215029 1.00065673 1.00002165 1.00010807]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00075899 1.00255299 1.00277917 1.00064775 1.0000211  0.99997848]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00161544 1.0027747  1.00349401 1.0004941  1.00002075 1.00015024]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00120704 1.00335822 1.00300489 1.00048699 1.00002025 1.00001958]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00160268 1.00417062 1.00319642 1.00056693 1.00001979 1.00002557]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00144025 1.00593262 1.00311508 1.00052527 1.00001932 0.99989922]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00118962 1.00611641 1.00271779 1.00054117 1.00001706 0.99998218]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00103921 1.00644305 1.00221962 1.00041596 1.00001667 0.99993706]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00126686 1.00771006 1.00247129 1.00046291 1.00001634 0.99998543]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00160529 1.00942329 1.00307134 1.00059471 1.00001578 1.00013703]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00241654 1.00991575 1.00386145 1.00062542 1.00001527 0.99992936]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.534  -0.181  +0.189
# Beta  = 0.552  -0.127  +0.127
# Sigma = 0.528  -0.179  +0.172
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -1.496  -0.219  +0.151
# Beta  = 0.529  -0.105  +0.150
# Sigma = 0.488  -0.139  +0.212
# The 90% lower limit on beta from all values
# Beta > 0.396
# The 90% upper limit on beta from all values
# Beta < 0.733
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -1.496  -0.219  +0.151
# Beta =  0.529  -0.105  +0.150
# Sigma =  0.488  -0.139  +0.212
# The 90% lower limit on beta from run results
# Beta >  0.4
# The 90% upper limit on beta from run results
# Beta <  0.73

# %%
# Try with another seed
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=76, parallel=False, min_iter=5000, max_iter=20000)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=20000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.13926138 0.9982224  1.10139009 1.03482431 1.00266281 1.09015589]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.10475972 1.01073569 1.08196505 1.00892237 0.99995969 1.05776631]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06940984 1.02008552 1.06987561 1.02340677 1.00105932 1.04528115]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.09207282 1.00137284 1.09256562 1.0144659  1.00139448 1.05486993]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02837702 1.00208217 1.03543233 1.00726901 0.99943831 1.0189112 ]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00426722 1.00558724 1.00995758 1.00416103 0.99994969 1.01037658]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00130267 1.02015708 1.00556652 1.00381702 0.99995825 1.01935863]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00788936 1.01894474 1.00551551 1.00293783 0.99923878 1.01422489]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00902556 1.03345231 1.01005816 1.0033278  0.99933785 1.01603153]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01673646 1.04372365 1.02199408 1.00241712 0.99930984 1.01749607]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0176657  1.05454125 1.02367662 1.0021369  0.99938002 1.01388537]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01590054 1.05633555 1.0194348  1.00323744 0.99940076 1.01118862]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01056554 1.06531805 1.01451419 1.00179562 0.99941871 1.00832557]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0155795  1.06769639 1.01693573 1.00106207 0.99952832 1.00622962]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01820767 1.05976081 1.01678814 1.001742   0.99956245 1.00306073]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02325    1.04626826 1.02019669 1.00099239 0.99946705 1.00255018]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03812899 1.06688756 1.03185628 1.00072546 0.99951101 1.00233382]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05598232 1.09320059 1.04511076 1.00024633 0.99953443 1.00045232]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07788421 1.11801966 1.06063077 1.00032852 0.99953686 1.00087094]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.09291714 1.13546448 1.07290326 1.00032718 0.99956074 1.0010502 ]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.11301917 1.15154457 1.08824335 1.00071961 1.00004612 1.00238269]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.13492043 1.14613496 1.10704551 1.00057625 1.00002576 1.00432573]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.15050537 1.15332315 1.12158359 1.00018764 0.9999923  1.00632265]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.16026863 1.16257687 1.13483971 0.99996285 0.99997558 1.00904363]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.17608285 1.17354066 1.15032833 0.99999006 1.00029552 1.01139189]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.19049403 1.19591103 1.16464745 1.00019294 1.00028212 1.01061891]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.2017107  1.20473113 1.1746944  1.00039541 1.00026941 1.01188995]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.21184646 1.19266679 1.18385576 1.00022883 1.00025118 1.01454956]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.22429717 1.19511705 1.1971317  1.00039855 1.0002494  1.01733225]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.2369307  1.18512536 1.20615155 1.00018016 1.00024042 1.01933906]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.24344612 1.17795256 1.21088821 0.99994802 1.00022765 1.02117421]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.24946278 1.17210092 1.21817051 0.99977036 1.00022002 1.02324356]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.25383913 1.16434852 1.22409065 0.99977357 1.00021178 1.02604367]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.25733037 1.16350956 1.22861546 0.99978597 1.00020904 1.02675835]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.24840452 1.15855568 1.22086302 0.99984597 1.00020129 1.02694257]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.23560938 1.14974538 1.20822985 0.99981215 1.00019128 1.02627464]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.2189102  1.14163537 1.18988296 0.9997654  1.00018656 1.0238863 ]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.21020736 1.1342776  1.1811448  0.99989401 1.00018721 1.02365118]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.20607459 1.1325825  1.17771851 0.99987248 0.99999992 1.02091482]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.20251172 1.13278741 1.17605022 0.99979393 0.99999992 1.02024111]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.19906871 1.129774   1.17481965 0.99987438 0.99999992 1.02052025]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.18942654 1.12313795 1.16456199 0.99987734 0.99999993 1.01857487]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.17907782 1.11799855 1.15695568 0.99993422 0.99999993 1.01781381]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.1755702  1.12162441 1.15507115 0.99993626 0.99999994 1.01624977]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.17026975 1.12240514 1.15191547 0.99993688 0.99999996 1.01411739]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.16812876 1.11689698 1.15000237 0.99994104 0.99999992 1.01466214]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.15853331 1.10847459 1.14329641 0.99998277 0.99999993 1.01480365]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.14798285 1.10035369 1.13259905 1.00002865 0.99999993 1.01381133]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.1404476  1.09331944 1.12629631 1.00011249 0.99999993 1.01296705]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.13327006 1.08843632 1.11919882 1.00022494 0.99999993 1.01215563]
#
# Iteration:  5100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.12476782 1.07908443 1.11313268 1.00029058 0.99999993 1.01259944]
#
# Iteration:  5200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.11564094 1.0712867  1.10649768 1.00020833 0.99999987 1.01233308]
#
# Iteration:  5300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.10530465 1.06766711 1.09880913 1.00010545 0.99999988 1.01145293]
#
# Iteration:  5400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.09856361 1.06380059 1.09029754 1.00000616 0.99999988 1.01044461]
# Length of chain: 10800

# %%
linmix_results(N_runs=1, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10800,) (10800,) (10800,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.880  -0.479  +0.406
# Beta  = 0.656  -0.239  +0.282
# Sigma = 0.782  -0.369  +0.439
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -1.722  -0.637  +0.248
# Beta  = 0.564  -0.148  +0.373
# Sigma = 0.635  -0.221  +0.586
# The 90% lower limit on beta from all values
# Beta > 0.385
# The 90% upper limit on beta from all values
# Beta < 1.108
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -1.722  -0.637  +0.248
# Beta =  0.564  -0.148  +0.373
# Sigma =  0.635  -0.221  +0.586
# The 90% lower limit on beta from run results
# Beta >  0.39
# The 90% upper limit on beta from run results
# Beta <  1.11

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True,  min_iter=2000, max_iter=10000)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# 100%|██████████| 100/100 [02:29<00:00,  1.50s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (594400,) (594400,) (594400,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.667  -0.242  +0.247
# Beta  = 0.643  -0.197  +0.198
# Sigma = 0.653  -0.233  +0.231
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -1.619  -0.290  +0.199
# Beta  = 0.601  -0.155  +0.239
# Sigma = 0.597  -0.178  +0.287
# The 90% lower limit on beta from all values
# Beta > 0.409
# The 90% upper limit on beta from all values
# Beta < 0.932
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -1.622  -0.260  +0.175
# Beta =  0.609  -0.135  +0.197
# Sigma =  0.600  -0.156  +0.253
# The 90% lower limit on beta from run results
# Beta >  0.44
# The 90% upper limit on beta from run results
# Beta <  0.88

# %% [markdown]
# ### 1000 Runs

# %%
run_linmix(N_runs=1000, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True)

# %%
linmix_results(N_runs=1000, interp= True, type_source="NS")

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data NS

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=False, type_source="NS", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_paired_NS_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01912901 1.00352261 1.03847647 1.01678258 0.99849386 1.00045371]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03878767 1.08994998 1.03860658 1.00576829 1.01178878 1.03605954]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06597542 1.10542139 1.08084365 1.02249313 1.01416464 1.0715752 ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04099912 1.0636557  1.0479889  1.0109819  1.00252478 1.04813423]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03405752 1.04462074 1.02731794 1.00067463 1.00282454 1.03559349]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05129905 1.07510778 1.04622536 1.00115724 0.99987302 1.05624266]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04547267 1.11947691 1.04780669 1.00262901 0.99975792 1.05256848]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06931331 1.09843248 1.06720751 1.00119974 0.99986308 1.04516154]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06773148 1.10346979 1.07013904 1.00327231 0.99987495 1.05143693]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07181657 1.13434165 1.05909518 1.00342698 1.00011554 1.04513653]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05555092 1.17568759 1.03923689 1.00198024 1.00014356 1.04410911]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03815167 1.20919227 1.02578473 0.9999515  0.99987055 1.05520929]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01744415 1.24288184 1.01476932 1.00165129 0.9998818  1.07451186]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01979306 1.27188418 1.01356242 1.00163599 1.00062224 1.0935235 ]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02770628 1.2849067  1.02117861 1.00028384 1.00008144 1.11023638]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03201617 1.29916192 1.02935401 0.9998652  1.00007657 1.13223307]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02983044 1.2720676  1.03537461 0.99978722 1.00007053 1.13561095]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02883263 1.22082088 1.03950126 0.99969066 1.00006345 1.12855983]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02913765 1.19036122 1.04388133 0.99987292 1.00005734 1.12691277]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02663876 1.17572479 1.04308826 1.00033711 1.00005329 1.12579448]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02123754 1.16658106 1.03516216 1.00053052 1.0000507  1.12010111]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02055129 1.16489985 1.03556298 1.00013481 1.00001196 1.12375936]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02180542 1.16635842 1.03573965 1.00038452 1.00035853 1.12327908]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02574026 1.16578619 1.0362852  1.00108333 1.00030947 1.1183914 ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03161468 1.1699691  1.03745266 1.00108694 1.00027729 1.11495092]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03765748 1.16929412 1.04035797 1.00102686 1.00003748 1.10630674]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04366718 1.16403456 1.04188066 1.00120106 1.00003358 1.09376239]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.04693162 1.15502067 1.04246501 1.00123724 1.00029263 1.08549444]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.05460735 1.1500927  1.04723054 1.00120545 1.00028096 1.08115389]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06557937 1.1365756  1.05604451 1.00115323 1.00027525 1.07691766]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07228137 1.12851878 1.05846018 1.00066945 1.00026736 1.07251124]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07383931 1.12626008 1.05927321 1.00038013 1.00025985 1.07208948]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07295644 1.12679346 1.05885302 1.00042803 1.00025171 1.06899587]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07523105 1.12406142 1.06306499 1.00057429 1.00024406 1.06679934]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07866399 1.12524427 1.06508105 1.00049129 1.00017259 1.06560594]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.08211792 1.12446484 1.06779696 1.0001414  1.00016164 1.06435661]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.08315114 1.11451866 1.06846492 0.99992835 1.00015721 1.06171319]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.08132825 1.10715856 1.06868699 0.99987081 1.00015171 1.06191829]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07960141 1.1005018  1.06577733 0.99989053 1.00014771 1.06029749]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0769541  1.09146445 1.06110169 0.99999628 1.00014389 1.05656572]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07312879 1.08432274 1.05662308 1.00007121 1.00013952 1.05528739]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07290603 1.07397966 1.0546668  1.00022422 1.00013625 1.05127921]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07405775 1.06258227 1.05737697 1.0001691  1.00013297 1.04731009]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07309533 1.05493456 1.05910824 1.00024354 1.00012999 1.04341317]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07318836 1.05246883 1.06017726 1.00032668 1.00012773 1.0414804 ]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0748196  1.05240243 1.06136689 1.00060659 1.00012239 1.0388185 ]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0752336  1.05093284 1.0635579  1.00073437 1.00011969 1.03692455]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07602837 1.04802697 1.06297439 1.00058502 1.00011709 1.03435445]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07573687 1.04647425 1.06214714 1.00046903 1.00011453 1.03251961]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.07397424 1.04543831 1.06069623 1.00058765 1.0001114  1.03109923]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= False, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -3.433  -1.284  +1.267
# Beta  = 1.261  -0.675  +0.719
# Sigma = 2.352  -1.178  +1.193
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -3.262  -1.456  +1.096
# Beta  = 1.195  -0.609  +0.785
# Sigma = 2.188  -1.014  +1.357
# The 90% lower limit on beta from all values
# Beta > 0.441
# The 90% upper limit on beta from all values
# Beta < 2.212
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -3.262  -1.456  +1.096
# Beta =  1.195  -0.609  +0.785
# Sigma =  2.188  -1.014  +1.357
# The 90% lower limit on beta from run results
# Beta >  0.44
# The 90% upper limit on beta from run results
# Beta <  2.21

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data NSs, No Upper Limits

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, include_Fr_uplims=False)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  False
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 4
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99120377 0.99708096 1.02432577 1.03450495 1.00994385 1.0101001 ]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99915256 0.99983513 0.99505365 1.02398838 1.00228681 0.99978822]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00128242 0.99722053 1.00215888 1.01015936 1.00111693 0.99864984]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0016486  0.99773551 1.00983661 1.00624302 1.00084728 0.99992005]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00129361 0.99892008 1.01329689 1.00516448 1.00058638 1.00468073]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99941918 0.99928675 1.0103189  1.00708739 1.00033121 1.00538881]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99911811 0.99962946 1.00894233 1.00427864 0.9992428  1.00455424]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99933468 1.00000525 1.008194   1.00170778 0.99997941 1.00215827]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99954043 1.00075316 1.00442297 1.00181193 0.99998212 1.00342583]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00055516 1.0006406  1.00594749 1.00181465 0.99998325 1.00295696]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00091686 1.0007256  1.01161094 1.00009237 0.99998362 1.00435853]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013143 1.00155722 1.0080841  0.99990014 0.99997784 1.00456521]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985211 1.00052203 1.00611566 1.00020218 0.99997856 1.00381891]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016146 0.99986923 1.00456975 1.00081077 0.99998545 1.00247189]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058356 0.99983315 1.00416054 1.00083836 0.99998655 1.00114738]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003653 0.99957913 1.00211182 1.00156606 0.99998693 1.00023111]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015478 0.99953366 1.00165796 1.00307564 0.99998736 0.99987491]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010028 0.99953546 1.00146645 1.00214305 0.99998735 1.00068405]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016825 0.99996842 1.00295368 1.00192469 0.99998824 1.00181163]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007491 1.00029921 1.00288991 1.00146318 0.99998854 1.00184043]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00067338 1.00019229 1.00396397 1.00088874 0.99998849 1.00134793]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00072566 1.00021923 1.00396401 1.00048429 0.99998917 1.00135827]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00052828 1.00002836 1.00356464 0.99978053 0.99999442 1.00074314]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035642 1.00014592 1.0031601  0.99972947 0.99999455 1.00084515]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021651 1.00021551 1.00292913 0.9997731  0.99999484 1.00070466]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013741 1.00044619 1.00258489 0.99986132 1.00000049 1.00096551]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015375 1.00029985 1.00255409 1.00014713 0.99999925 1.00157269]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017339 1.00008375 1.00186866 1.00031765 0.99999913 1.00095972]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008913 1.00004787 1.00094342 1.00032155 0.9999991  1.00060243]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007134 1.00014477 1.00080724 1.00009655 0.99999874 1.00049372]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000027   1.0001126  1.00075885 1.00006504 0.99999874 1.00047949]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999805 1.00008882 1.00061666 1.00016008 0.99998665 1.00055197]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999355 1.00015036 1.00084089 1.00008529 0.99998716 1.00072131]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000109 1.00008507 1.0005504  1.00008992 0.99998696 1.000685  ]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001721 1.00009102 1.00049829 0.99985447 0.99998724 1.00072956]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997984 0.99995396 1.00053372 0.99984836 0.99998674 1.00041927]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999354 0.99999507 1.00035135 0.99993228 0.99999041 1.00052876]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000848 0.99997914 1.00034319 0.99985648 0.99999064 1.00043698]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008342 0.99995801 1.00036629 0.99981652 0.99999063 1.00022564]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006188 0.99986652 1.00034719 0.9998779  0.99999092 1.00022599]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017574 0.9998271  1.00042839 0.99986472 1.00001085 1.00010456]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018588 0.99981584 1.00042172 0.99983572 1.00001018 1.00006583]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00020328 0.99986954 1.00056763 0.99986222 1.00000921 1.00018196]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027908 0.99986528 1.00062473 0.99984908 1.00000908 1.00023828]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030431 0.99990823 1.00059868 0.99988191 1.00000878 1.00025999]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023126 0.99985885 1.00026315 0.99985188 1.0000103  1.00026685]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002063  0.99988442 1.00027603 0.99986098 1.00000917 1.00027995]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023545 0.99988015 1.00043141 0.99984485 1.00000897 1.0003368 ]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024942 0.99986282 1.00037058 0.99985169 1.00000885 1.00036223]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002382  0.99987886 1.00048915 0.99988572 1.00001322 1.00042924]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# Include X-ray upper limits?:  False
# Include radio upper limits?:  False
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 4
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.981  -0.063  +0.062
# Beta  = 0.229  -0.064  +0.064
# Sigma = 0.177  -0.076  +0.071
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.976  -0.068  +0.057
# Beta  = 0.230  -0.065  +0.063
# Sigma = 0.157  -0.056  +0.090
# The 90% lower limit on beta from all values
# Beta > 0.143
# The 90% upper limit on beta from all values
# Beta < 0.313
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.976  -0.068  +0.057
# Beta =  0.230  -0.065  +0.063
# Sigma =  0.157  -0.056  +0.090
# The 90% lower limit on beta from run results
# Beta >  0.14
# The 90% upper limit on beta from run results
# Beta <  0.31

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, interp=True, type_source="NS", K=3, seed=5, parallel=True, include_Fr_uplims=False)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  False
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 4
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# 100%|██████████| 100/100 [01:45<00:00,  1.05s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  False
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1630-47_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Aquila X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cen X-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Cir X-1_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/EXO 1846-031_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1739-278_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GRS 1915+105_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/H1743-322_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/IGR J17091-3624_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1348-630_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1803-298_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1807+132_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1810-222_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1816-195_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1808.4-3658_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/SAX J1810.8-2609_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1727.8-1613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1728.9-3613_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1842.5-1124_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/Swift J1858.6-0814_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/XTE J1701-462_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['1A 1744-361' 'Aquila X-1' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 4
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.056  -0.148  +0.151
# Beta  = 0.220  -0.146  +0.148
# Sigma = 0.306  -0.157  +0.158
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -1.034  -0.170  +0.129
# Beta  = 0.235  -0.162  +0.133
# Sigma = 0.258  -0.110  +0.205
# The 90% lower limit on beta from all values
# Beta > 0.008
# The 90% upper limit on beta from all values
# Beta < 0.411
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -1.053  -0.104  +0.096
# Beta =  0.220  -0.111  +0.111
# Sigma =  0.279  -0.081  +0.128
# The 90% lower limit on beta from run results
# Beta >  0.07
# The 90% upper limit on beta from run results
# Beta <  0.37
