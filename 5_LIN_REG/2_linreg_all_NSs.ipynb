# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, min_iter=5000, max_iter=20000)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 5
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=20000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03706198 1.04495214 1.00436239 1.0183307  0.99786033 0.99726674]
#
# Iteration:  200
# ...

# %%
linmix_results(N_runs=1, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 5
# (20000,) (20000,) (20000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.191  -0.519  +0.521
# Beta  = 0.624  -0.280  +0.291
# Sigma = 1.092  -0.479  +0.490
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data NSs

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, min_iter=5000, max_iter=10000)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=10000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.29324865 1.01609792 1.32402299 1.05770057 1.0016053  1.15175497]
#
# Iteration:  200
# ...

# %%
linmix_results(N_runs=1, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (12400,) (12400,) (12400,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.582  -0.829  +0.723
# Beta  = 0.987  -0.434  +0.452
# Sigma = 1.636  -0.650  +0.749
# ...

# %%
# With additional SAX J1808 point
linmix_results(N_runs=1, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.646  -0.918  +0.813
# Beta  = 0.769  -0.372  +0.402
# Sigma = 1.756  -0.765  +0.835
# ...

# %% [markdown]
# # 2 Runs

# %%
run_linmix(N_runs=2, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True,  min_iter=5000, max_iter=10000)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_2
# 100%|██████████| 2/2 [00:00<00:00, 130.52it/s]

# %%
linmix_results(N_runs=2, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_2
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (26400,) (26400,) (26400,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.463  -0.619  +0.644
# Beta  = 0.953  -0.440  +0.440
# Sigma = 1.540  -0.587  +0.548
# ...

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True,  min_iter=5000, max_iter=10000)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 5
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# 100%|██████████| 100/100 [03:52<00:00,  2.32s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 5
# (1603200,) (1603200,) (1603200,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -3.320  -1.261  +1.272
# Beta  = 0.781  -0.596  +0.629
# Sigma = 2.126  -1.149  +1.142
# ...

# %%
linmix_results(N_runs=100, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (1507400,) (1507400,) (1507400,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.932  -1.028  +1.015
# Beta  = 1.089  -0.595  +0.610
# Sigma = 1.987  -0.963  +0.972
# ...

# %%
# With additional SAX J1808 point
linmix_results(N_runs=100, interp= True, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.347  -0.660  +0.663
# Beta  = 0.831  -0.405  +0.401
# Sigma = 1.480  -0.648  +0.653
# ...

# %% [markdown]
# ### 1000 Runs

# %%
run_linmix(N_runs=1000, interp=True, type_source="NS", K=3, seed=5, parallel=True, verbose=True)

# %%
linmix_results(N_runs=1000, interp= True, type_source="NS")

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data NS

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=False, type_source="NS", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# DIRECTORY:  ./MCMC_parfiles_paired_NS_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# ...

# %%
linmix_results(N_runs=1, interp= False, type_source="NS")
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_NS_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data NSs, No Upper Limits

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, include_Fr_uplims=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99472501 1.00625412 1.18027719 1.02657495 1.00267873 1.06868301]
#
# Iteration:  200
# ...

# %%
linmix_results(N_runs=1, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.034  -0.158  +0.140
# Beta  = 0.209  -0.185  +0.181
# Sigma = 0.476  -0.309  +0.190
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# ...

# %%
run_linmix(N_runs=1, interp=True, type_source="NS", K=3, seed=5, parallel=False, include_Fr_uplims=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99178073 1.0024533  0.99631697 1.0048462  0.99735614 0.99095229]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# ...

# %%
linmix_results(N_runs=1, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.799  -0.344  +0.357
# Beta  = 0.669  -0.388  +0.396
# Sigma = 1.138  -0.674  +0.458
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# ...

# %%
# With additional SAX J1808 point
linmix_results(N_runs=1, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.786  -0.243  +0.237
# Beta  = 0.692  -0.265  +0.264
# Sigma = 0.719  -0.336  +0.273
# ...

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, interp=True, type_source="NS", K=3, seed=5, parallel=True, include_Fr_uplims=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 2
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# 100%|██████████| 100/100 [01:56<00:00,  1.17s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 2
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.174  -0.280  +0.598
# Beta  = -0.075  -0.438  +0.910
# Sigma = 5.434  -5.139  +-3.089
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# ...

# %%
linmix_results(N_runs=100, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.800  -0.336  +0.338
# Beta  = 0.604  -0.436  +0.426
# Sigma = 1.072  -0.653  +0.405
# ...

# %%
# With additional SAX J1808 point
linmix_results(N_runs=100, interp= True, type_source="NS", include_Fr_uplims=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_no_Fr_uplims_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['1A 1744-361', '4U 1543-47', '4U 1630-47', 'Cen X-4', 'Cir X-1', 'EXO 1846-031', 'GRS 1739-278', 'GRS 1915+105', 'GX 339-4', 'H1743-322', 'IGR J17091-3624', 'MAXI J1348-630', 'MAXI J1631-479', 'MAXI J1803-298', 'MAXI J1807+132', 'MAXI J1810-222', 'MAXI J1816-195', 'MAXI J1820+070', 'SAX J1808.4-3658', 'SAX J1810.8-2609', 'Swift J1727.8-1613', 'Swift J1728.9-3613', 'Swift J1842.5-1124', 'Swift J1858.6-0814', 'Vela X-1', 'XTE J1701-462']
# Sources included after filtering:  ['MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 3
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.804  -0.240  +0.241
# Beta  = 0.624  -0.303  +0.294
# Sigma = 0.678  -0.329  +0.273
# ...
