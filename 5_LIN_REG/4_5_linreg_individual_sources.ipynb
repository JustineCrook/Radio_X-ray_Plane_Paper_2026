# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %%
linmix_results_individual_sources(N_runs=100, names=["4U 1543-47", "GX 339-4", "MAXI J1631-479" ,"MAXI J1820+070"], interp=True, save_name="lin_reg_individual_sources")
# Out:
# 4U 1543-47
# ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['4U 1543-47']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.823  -0.102  +0.109
# Beta  = 0.903  -0.127  +0.127
# Sigma = 0.254  -0.064  +0.062
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.838  -0.117  +0.094
# Beta  = 0.903  -0.126  +0.127
# Sigma = 0.241  -0.051  +0.075
# The 90% lower limit on beta from all values
# Beta > 0.738
# The 90% upper limit on beta from all values
# Beta < 1.070
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.823  -0.108  +0.108
# Beta =  0.903  -0.126  +0.127
# Sigma =  0.241  -0.051  +0.075
# The 90% lower limit on beta from run results
# Beta >  0.74
# The 90% upper limit on beta from run results
# Beta <  1.07
# GX 339-4
# ./MCMC_parfiles_interp_['GX 339-4']_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['GX 339-4']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/GX 339-4_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.553  -0.057  +0.056
# Beta  = 0.583  -0.027  +0.027
# Sigma = 0.258  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.554  -0.058  +0.055
# Beta  = 0.582  -0.026  +0.027
# Sigma = 0.257  -0.021  +0.024
# The 90% lower limit on beta from all values
# Beta > 0.549
# The 90% upper limit on beta from all values
# Beta < 0.618
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.553  -0.028  +0.028
# Beta =  0.582  -0.026  +0.027
# Sigma =  0.257  -0.021  +0.024
# The 90% lower limit on beta from run results
# Beta >  0.55
# The 90% upper limit on beta from run results
# Beta <  0.62
# MAXI J1631-479
# ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['MAXI J1631-479']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1631-479_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.241  -0.105  +0.105
# Beta  = 0.195  -0.034  +0.034
# Sigma = 0.128  -0.047  +0.044
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.241  -0.105  +0.105
# Beta  = 0.194  -0.034  +0.035
# Sigma = 0.115  -0.034  +0.057
# The 90% lower limit on beta from all values
# Beta > 0.149
# The 90% upper limit on beta from all values
# Beta < 0.241
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.242  -0.060  +0.057
# Beta =  0.194  -0.034  +0.035
# Sigma =  0.115  -0.034  +0.057
# The 90% lower limit on beta from run results
# Beta >  0.15
# The 90% upper limit on beta from run results
# Beta <  0.24
# MAXI J1820+070
# ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['MAXI J1820+070']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/MAXI J1820+070_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.045  -0.061  +0.063
# Beta  = 0.505  -0.022  +0.022
# Sigma = 0.130  -0.019  +0.019
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.049  -0.066  +0.058
# Beta  = 0.505  -0.022  +0.023
# Sigma = 0.129  -0.017  +0.021
# The 90% lower limit on beta from all values
# Beta > 0.476
# The 90% upper limit on beta from all values
# Beta < 0.534
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.045  -0.032  +0.033
# Beta =  0.505  -0.022  +0.023
# Sigma =  0.129  -0.017  +0.021
# The 90% lower limit on beta from run results
# Beta >  0.48
# The 90% upper limit on beta from run results
# Beta <  0.53
