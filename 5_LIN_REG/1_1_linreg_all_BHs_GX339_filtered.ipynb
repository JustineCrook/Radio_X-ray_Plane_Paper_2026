# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# In this notebook, I similarly use the interpolated BH data -- but I only include the GX 339 data used to define the standard track.

# %% [markdown]
# # One run using the best distance estimate

# %%
run_linmix(N_runs=1, interp=True, type_source="BH", gx_339_filtered=True, K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# True
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# Number of GX 339-4 data points: 70
# DIRECTORY:  ./MCMC_parfiles_interp_BH_GX339_filtered_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9932398  1.02020938 1.02149469 1.00509154 1.003895   0.99994404]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9966884  1.00652692 1.01085904 1.00462284 1.00212001 0.99541163]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99719457 1.00639786 1.00323913 1.00042168 1.00061071 1.00224862]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99795632 1.00189472 1.00042524 1.00001643 1.00044188 1.00224814]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9991005  0.99993209 1.00321175 1.000673   1.00037494 1.00274344]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003636 0.99937132 1.00249532 1.00126839 1.00019833 1.00072722]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00033353 1.00092745 1.00109509 1.00107035 1.0001448  1.00021306]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039987 1.00092087 1.00082946 1.00035088 0.99996681 0.9994523 ]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00042613 0.99983902 1.0006338  0.99974594 0.99996965 0.9997208 ]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00077235 0.99976171 1.00064896 0.99946947 0.99997173 0.99975858]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069006 0.99969626 1.00117499 1.0003602  0.99997433 0.99965629]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00118606 1.00064906 1.00123833 1.00002632 0.99997644 0.99951488]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00290358 1.0007974  1.00170372 0.9997189  0.9999792  0.99945066]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00250311 1.00047696 1.00169609 0.99970188 0.99998022 0.99950158]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00233495 1.00020615 1.00187387 0.99992614 0.99998177 0.99962683]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00286438 1.00077472 1.00201726 0.99967196 0.99998317 0.99971533]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00226232 1.00063116 1.00184097 0.99962156 0.99998121 0.99985866]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0021459  1.00067786 1.0019461  0.99951315 0.99998277 0.99989092]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00186411 1.00059921 1.00107072 0.99964329 0.99984546 1.00011555]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00192849 1.00055911 1.00104049 0.99969815 0.99985342 1.00014528]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00152614 1.00056415 1.0010523  0.99981362 0.99986042 1.0004308 ]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00152396 1.00033137 1.00080872 0.99976524 0.99986663 1.00033052]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139971 1.00058217 1.0006778  0.99974672 0.99987239 1.00031693]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00098214 1.00052991 1.0007107  0.99981821 0.9998767  1.000367  ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0010439  1.00059457 1.0004807  0.99991794 0.99988135 1.0001422 ]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0012444  1.00038686 1.00043076 0.99981116 0.99988572 1.00017624]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00094528 1.00031495 1.00027464 0.99986435 0.99988971 1.00007364]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00092151 1.00047849 1.00043003 0.99994692 0.99989373 1.00006114]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00094025 1.00042187 1.00037148 0.99995945 0.99989647 1.00002264]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0005354  1.00045916 1.00036755 1.00000465 0.99990011 1.00004475]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039378 1.00032604 1.00029197 0.99996916 0.99990334 1.0000103 ]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023667 1.00049385 1.00048134 0.99993138 0.99990624 0.99989035]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023338 1.00055818 1.00037175 0.99990967 0.9999092  0.99988886]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018369 1.00074245 1.00046286 0.99992915 0.99991177 0.999909  ]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002244  1.00084222 1.00036439 1.00005736 0.99991428 0.99984756]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00026812 1.00097699 1.00028162 1.00005835 0.99992798 0.99992408]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00028686 1.00100735 1.00029513 1.000055   0.99992996 0.99996252]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018485 1.00080194 1.00033129 1.00005604 0.99993179 0.99997469]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00020087 1.00079206 1.00037389 1.00019853 0.99993038 0.99988314]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016729 1.00093298 1.00030583 1.00021491 0.99993194 0.99985897]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018643 1.00084884 1.00021848 1.0002794  0.99993338 0.99985564]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013268 1.00091975 1.00020393 1.00022    0.99993479 0.99986136]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015896 1.00077298 1.00014366 1.00017797 0.99993633 0.99986557]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00029286 1.00074716 1.0001571  1.00016724 0.99993778 0.99985976]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024179 1.000564   1.00023739 1.00017244 0.99993927 0.99986014]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023269 1.00050523 1.00019539 1.00012339 0.99994065 0.99986036]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00022299 1.00045673 1.0001542  1.00014437 0.99994184 0.99984809]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021722 1.00045202 1.00021479 1.00012205 0.99994311 0.99986729]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024801 1.00039183 1.00017451 1.00015005 0.99994436 0.9999007 ]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00028948 1.00039253 1.0001435  1.0001052  0.99994529 0.9998859 ]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= True, type_source="BH", gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_GX339_filtered_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# True
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# Number of GX 339-4 data points: 70
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.071  -0.033  +0.033
# Beta  = 0.576  -0.024  +0.024
# Sigma = 0.431  -0.024  +0.024
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.071  -0.033  +0.033
# Beta  = 0.576  -0.024  +0.024
# Sigma = 0.430  -0.023  +0.025
# The 90% lower limit on beta from all values
# Beta > 0.544
# The 90% upper limit on beta from all values
# Beta < 0.607
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.071  -0.033  +0.033
# Beta =  0.576  -0.024  +0.024
# Sigma =  0.430  -0.023  +0.025
# The 90% lower limit on beta from run results
# Beta >  0.54
# The 90% upper limit on beta from run results
# Beta <  0.61

# %% [markdown]
# ### 100 runs

# %%
run_linmix(N_runs=100, interp=True, type_source="BH", K=3, seed=5, parallel=True, verbose=True, gx_339_filtered=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# True
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# Number of GX 339-4 data points: 70
# DIRECTORY:  ./MCMC_parfiles_interp_BH_GX339_filtered_Nruns_100
# 100%|██████████| 100/100 [04:48<00:00,  2.89s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="BH", gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_GX339_filtered_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# True
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# Number of GX 339-4 data points: 70
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.075  -0.042  +0.042
# Beta  = 0.573  -0.028  +0.028
# Sigma = 0.426  -0.032  +0.032
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.076  -0.043  +0.042
# Beta  = 0.573  -0.028  +0.028
# Sigma = 0.424  -0.030  +0.033
# The 90% lower limit on beta from all values
# Beta > 0.537
# The 90% upper limit on beta from all values
# Beta < 0.610
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.075  -0.032  +0.032
# Beta =  0.573  -0.024  +0.024
# Sigma =  0.425  -0.023  +0.025
# The 90% lower limit on beta from run results
# Beta >  0.54
# The 90% upper limit on beta from run results
# Beta <  0.6
