# %% [markdown]
# In this notebook, I similarly use the interpolated BH data -- but I only include the GX 339 data used to define the standard track.

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# # One run using the best distance estimate

# %%
run_linmix(N_runs=1, interp=True, type_source="BH", gx_339_filtered=True, K=3, seed=5, parallel=False)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  True
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# ...

# %%
linmix_results(N_runs=1, interp= True, type_source="BH", gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_GX339_filtered_Nruns_1
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  True
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# ...

# %% [markdown]
# ### 100 runs

# %%
run_linmix(N_runs=100, interp=True, type_source="BH", K=3, seed=5, parallel=True, verbose=True, gx_339_filtered=True)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  True
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# ...

# %%
linmix_results(N_runs=100, interp= True, type_source="BH", gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_GX339_filtered_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  True
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/1A 1744-361_Lr_Lx_interp_akima.csv
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# ...

# %%
# Compared to before Lx0 was changed
ans = 10**0.07 * (7.51/5.47)**0.57
ans = np.log10(ans)
print(ans)
# Out:
# 0.14846198808232042
