# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Interpolated Data, BHs

# %% [markdown]
# ### One run using the best distance estimates

# %%
run_linmix(N_runs=1, interp=True, type_source="BH", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00333476 1.0011122  0.99632658 1.01967811 1.00206326 0.99700561]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01025311 1.01469895 1.00288346 1.00722573 0.99989718 0.99586184]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00117326 1.01350373 1.00487351 1.00810831 1.00651282 1.00092397]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00299381 1.00504587 1.00470775 1.00359801 1.00254405 0.99970947]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00203975 1.00242571 0.99838986 1.00091874 1.00163149 1.00173834]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00083859 1.00246245 0.99838398 1.00101507 1.00292699 1.00106691]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00062811 1.00432475 0.99906241 1.00165805 1.00318938 1.00200642]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985239 1.00340798 0.99994142 1.00283043 1.00262349 1.00185078]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00143219 1.002363   0.99961271 1.00214541 1.00252453 1.00115767]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00112366 1.00157576 0.99962931 1.00152564 1.00020304 0.99989887]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001243  1.00151557 1.00063919 1.00042127 1.0000539  0.99994442]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99950538 1.00072421 1.0007241  1.00034931 1.00012151 0.99991872]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99955737 1.00097601 1.00069551 1.00053359 0.99975619 0.99959844]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976857 1.00049469 1.00068405 1.00064666 0.99981012 0.99971915]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008561 1.00041639 1.00079876 1.00084968 0.99982344 0.99958077]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995368 1.00050443 1.00103326 1.00058255 0.99982917 0.99952273]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988841 1.00018166 1.00070091 1.00046477 0.99961475 0.99960215]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991806 1.0003905  1.00032803 1.00078732 0.99963448 0.99963187]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999003  1.00071217 1.00061939 1.00067478 0.99963365 0.99980838]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006428 1.00110355 1.00062611 1.000559   0.9996529  0.99996383]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032599 1.00078217 1.00021939 1.00044524 0.99970504 0.99960656]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0005408  1.00039761 1.00028264 1.00015039 0.99980354 0.99959137]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00076264 1.00055464 1.00035389 1.00010442 0.99978143 0.99966085]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00051128 1.00072157 1.00023779 1.00016007 0.99992932 0.99959628]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046991 1.00054615 1.00029569 1.00027402 0.99992141 0.99970009]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00055452 1.00059939 1.00000658 1.00029158 0.99985576 0.99976995]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069988 1.00037983 0.99997613 1.00014644 0.99985287 0.99972065]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0006618  1.00061216 0.99998566 1.00011297 0.99992067 0.99984929]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00075497 1.00066579 0.99992412 1.00007677 0.99992056 0.99982528]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00071093 1.00034129 0.999941   0.99993571 0.99989799 0.99978903]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00071331 1.00027161 0.99989076 0.9998202  0.99990765 0.99982992]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000634   1.00027758 0.999853   0.99976211 0.99991677 0.99988486]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0007672  1.00028457 0.99988562 0.99978871 0.99991912 0.99988368]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00055784 1.00025553 0.99985258 0.99985025 0.9999215  0.99993663]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038549 1.00030323 0.99996308 0.99987409 0.99989273 0.99990619]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00031929 1.00036065 0.99996456 0.9998843  0.99989872 0.99996855]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021495 1.00043341 0.99989783 0.99981704 0.99990375 1.00000776]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024972 1.00049785 0.99992778 0.99985719 0.99990835 1.00001781]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002425  1.00044054 0.99990139 0.99991285 1.00000027 1.00022209]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018318 1.00047306 0.99985773 0.9998713  0.99999941 1.00013694]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008671 1.00048394 0.99987157 0.99986916 0.99999943 1.00015542]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021654 1.00038525 0.999885   0.99982744 0.9999989  0.99998535]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000266   1.00057665 0.99992347 0.9998372  0.99999893 0.99995916]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024823 1.00078793 0.999885   0.99983126 0.999999   1.00000565]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00036653 1.00091593 0.999947   0.9998169  0.99999902 1.00002356]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037049 1.0009917  0.99995871 0.99980099 0.99999902 1.00004312]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037695 1.00101409 1.00001263 0.99986844 0.99999903 1.00004354]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045827 1.00078982 0.99995672 0.99989042 0.99999905 1.00001452]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034336 1.0007993  0.99994965 0.99996852 0.99999907 1.00001609]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024851 1.00062739 0.99996213 0.9999547  1.0000115  1.00009165]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= True, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.139  -0.034  +0.034
# Beta  = 0.569  -0.026  +0.026
# Sigma = 0.486  -0.025  +0.025
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.139  -0.034  +0.034
# Beta  = 0.570  -0.026  +0.025
# Sigma = 0.485  -0.024  +0.026
# The 90% lower limit on beta from all values
# Beta > 0.536
# The 90% upper limit on beta from all values
# Beta < 0.602
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.139  -0.034  +0.034
# Beta =  0.570  -0.026  +0.025
# Sigma =  0.485  -0.024  +0.026
# The 90% lower limit on beta from run results
# Beta >  0.54
# The 90% upper limit on beta from run results
# Beta <  0.6

# %% [markdown]
# ### 100 runs

# %%
run_linmix(N_runs=100, interp=True, type_source="BH", K=3, seed=5, parallel=True, verbose=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_100
# 100%|██████████| 100/100 [09:14<00:00,  5.55s/it]

# %%
linmix_results(N_runs=100, interp= True, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Aquila X-1' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479'
#  'MAXI J1803-298' 'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124'
#  'Swift J1858.6-0814' 'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.141  -0.043  +0.043
# Beta  = 0.567  -0.029  +0.029
# Sigma = 0.479  -0.032  +0.032
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.141  -0.044  +0.043
# Beta  = 0.567  -0.029  +0.030
# Sigma = 0.478  -0.031  +0.033
# The 90% lower limit on beta from all values
# Beta > 0.530
# The 90% upper limit on beta from all values
# Beta < 0.605
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.141  -0.034  +0.033
# Beta =  0.567  -0.025  +0.025
# Sigma =  0.478  -0.024  +0.026
# The 90% lower limit on beta from run results
# Beta >  0.53
# The 90% upper limit on beta from run results
# Beta <  0.6

# %% [markdown]
# # 1000 Runs

# %%
run_linmix(N_runs=1000, interp=True, type_source="BH", K=3, seed=5, parallel=True, verbose=True)

# %%
linmix_results(N_runs=1000, interp= True, type_source="BH")

# %% [markdown]
# ---

# %% [markdown]
# # With Additional Uncertainties

# %%
run_linmix(N_runs=1, interp=True, type_source="BH", K=3, seed=5, parallel=False, add_additional_error=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# Adding an additional error of 0.15 dex in quadrature to the x errors to see how this affects the results.
# The x errors after adding the additional error are:  [0.15579687 0.1555229  0.15657463 0.15860361 0.16034761]
# Adding an additional error of 0.15 dex in quadrature to the y errors to see how this affects the results.
# The y errors after adding the additional error are:  [0.15165283 0.15165555 0.15165472 0.15165199 0.151661  ]
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01247848 1.11133259 1.00804169 1.0120886  1.00135695 1.01261712]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02540993 1.01108622 0.99717171 1.00258938 1.00372091 0.99845157]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00941668 1.00253939 0.99852102 1.00489216 1.00059332 0.99915452]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0028687  0.99950646 1.00003897 1.00089357 1.00296496 0.99900807]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00192765 0.99912856 0.99894254 1.00228513 1.00080159 0.99866629]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00135959 1.00085866 0.99968892 1.00018162 1.00189107 1.00023846]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00153507 1.00005076 1.00027603 1.000366   0.99994035 0.99962192]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0000654  1.00053129 1.00045891 1.00012291 0.9995769  0.9989669 ]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00022167 1.00185926 1.00003923 1.00078723 0.99954494 0.99938825]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99954651 1.00127855 1.00029072 1.00025218 0.99950732 0.99923036]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976555 1.00154155 0.99983644 1.00001228 0.99955848 0.99974616]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974029 1.00115848 0.99994695 1.00059509 0.99983472 0.99963061]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999194 1.00146154 1.00016801 0.99995498 0.99983659 1.00012648]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010471 1.00153964 1.00061364 0.99992003 0.99984259 1.00034508]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976266 1.00130459 1.00084476 1.00013793 0.99984413 1.00025081]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9996917  1.00178081 1.00051501 1.00005367 0.9998465  1.00042215]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981674 1.00165189 1.00015652 1.0000169  0.99999366 0.999641  ]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972961 1.00150628 0.99974242 0.99996256 0.99999545 0.99957721]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99967018 1.00078817 0.99961055 0.99994633 0.99999185 0.99961706]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998265 1.00078178 0.99980268 0.99992572 0.99998771 0.99978741]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00042721 1.00100947 1.00026805 0.99992077 0.99998856 0.99984077]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037543 1.00063373 0.99998638 0.99995497 0.9999896  0.99978645]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001655  1.00073339 1.00011151 0.99985061 0.99998838 0.99978199]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00026405 1.00073139 1.00004054 0.99988361 0.99998881 0.99984956]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99994754 1.00080621 1.00002696 0.99984515 0.99999992 0.99987248]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982117 1.00084549 1.00001283 0.99978873 1.0000069  0.99991289]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99968962 1.00116545 1.00017404 0.99988089 1.00000794 1.00004143]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99967852 1.00125225 1.00016497 0.9998201  1.00000809 1.00000014]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99968255 1.00116224 0.99993779 0.99986731 1.00000916 1.00003418]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971995 1.00105385 0.99991058 0.99984385 1.0000145  1.0000933 ]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997281  1.00105485 1.00005116 0.99976877 1.00001058 1.00010006]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976943 1.00123395 1.00019792 0.99980261 1.00000872 1.00011346]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983455 1.00113142 1.00050109 0.99983217 1.00001154 1.00013695]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981657 1.00118463 1.00059366 0.99985164 1.00001657 1.0001693 ]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987771 1.00156814 1.00056105 0.99980163 1.00001491 1.00020899]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978401 1.00172724 1.00054829 0.99988702 1.00001415 1.00018945]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985994 1.0016726  1.00069351 0.99987833 1.00001386 1.00021065]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979806 1.00140895 1.00052488 0.99987574 1.00001536 1.00013717]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984614 1.00113021 1.00038925 0.99991143 1.00001165 1.00010503]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993576 1.00125485 1.00028468 0.99995602 1.00001202 1.00006834]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995831 1.00095111 1.00021589 0.99994904 1.00001023 1.00009222]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000399 1.00092375 1.00005687 0.99996237 1.00000981 1.00014778]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997791 1.00092469 1.00007283 0.99995826 1.00000908 1.00020597]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000055   1.00081311 1.00010947 0.999902   1.00000642 1.00019376]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00002544 1.00054863 1.00005444 0.99996289 1.00000959 1.00009113]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999744 1.00045604 0.99999806 0.99996284 1.00000937 1.00002778]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005842 1.00054435 1.00003659 0.99994471 1.00000791 1.00005358]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005808 1.00052919 1.00002984 0.99997342 0.99991435 1.0001543 ]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006927 1.00064278 1.00010624 1.0000263  0.99991173 1.00009382]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005262 1.00062644 1.00016679 1.00001544 0.99991345 1.0001448 ]
# Length of chain: 10000

# %%
# MCMC_parfiles_interp_BH_Nruns_1
linmix_results(N_runs=1, interp= True, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.131  -0.033  +0.033
# Beta  = 0.583  -0.025  +0.025
# Sigma = 0.451  -0.026  +0.026
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.131  -0.033  +0.033
# Beta  = 0.582  -0.025  +0.025
# Sigma = 0.450  -0.025  +0.027
# The 90% lower limit on beta from all values
# Beta > 0.551
# The 90% upper limit on beta from all values
# Beta < 0.615
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.131  -0.033  +0.033
# Beta =  0.582  -0.025  +0.025
# Sigma =  0.450  -0.025  +0.027
# The 90% lower limit on beta from run results
# Beta >  0.55
# The 90% upper limit on beta from run results
# Beta <  0.61

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data BHs

# %% [markdown]
# # One Run

# %%
run_linmix(N_runs=1, interp=False, type_source="BH", K=3, seed=5, parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['4U 1543-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070' 'Swift J1727.8-1613']
# Number of source: 12
# DIRECTORY:  ./MCMC_parfiles_paired_BH_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99276353 1.01641439 1.00596077 0.99947068 1.00348217 1.00272775]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.996142   1.0004265  1.00195272 1.00132885 1.00022923 0.99680504]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99907953 0.99726663 0.999504   1.00354548 0.99922442 0.996951  ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00383521 1.00254001 1.00507024 1.00311344 1.00008243 1.00232957]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00200414 0.99886184 1.00065922 1.00030911 1.0000648  1.00256724]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987093 0.99956953 1.00185335 0.99904573 1.00005105 1.00204008]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979168 1.00006972 1.00257627 0.99888093 1.00004237 1.00131348]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00178939 0.99927307 1.00313558 0.9994859  1.00003609 1.00137921]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00096757 0.99929749 1.00163359 0.99958542 1.00002928 1.00074612]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00266888 0.999397   1.00048637 0.99995658 1.00002542 1.0004298 ]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00080991 0.99951871 1.0018134  1.00075632 1.00002163 1.0004697 ]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00076548 1.00012761 1.00184583 1.00084395 1.00021691 1.0013286 ]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00040103 1.00036638 1.00196934 1.00076162 1.00018982 1.00096969]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034244 1.00042174 1.00144256 1.00065036 1.00017529 1.00096863]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008647 1.00083137 1.00269007 1.0004954  1.00016069 1.00073261]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008143 1.00059366 1.00157231 1.00097197 1.00015131 1.00052479]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00019008 1.00083064 1.00148931 1.00047323 1.00014371 1.00046196]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00062943 1.00103999 1.00172587 1.0005362  1.00022469 1.00120378]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046426 1.00073116 1.00067067 1.0008988  1.00021329 1.00098148]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024916 1.00049589 1.000553   1.00106686 1.0002021  1.00077964]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00059178 1.00130594 1.00044429 1.00095808 1.00018989 1.00032259]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00054034 1.00155707 1.0004649  1.00141281 1.00018182 1.00038238]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00086475 1.00200045 1.00054155 1.00143751 1.00017357 1.00044539]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00125117 1.00248676 1.00050694 1.00170901 1.00016479 1.00030714]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00136914 1.00306584 1.00065486 1.00164333 1.0001552  1.00014199]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00146951 1.00232851 1.00054437 1.0015896  1.00016472 1.0004401 ]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00132798 1.00197112 1.00037505 1.00155986 1.00015701 1.00026544]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139854 1.00230085 1.00027006 1.00134204 1.00014896 1.00015582]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00114406 1.00239335 1.00009872 1.00128373 1.0001417  1.00013351]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00130027 1.00252044 1.00013411 1.00142023 1.00013617 1.00000743]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00166546 1.00255716 1.00016792 1.00125114 1.00013078 0.99996511]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139592 1.00255982 1.00026289 1.00117257 1.00012591 0.99990881]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00124264 1.00250873 1.00036104 1.00123994 1.00012228 0.99989839]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00114533 1.00255206 1.00044062 1.00113533 1.00011913 0.99989983]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00108169 1.00227123 1.00034184 1.00118191 1.00011614 0.99994053]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00117421 1.00293075 1.00033846 1.0010264  1.00011343 0.99998158]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00123784 1.00295265 1.00044908 1.00088158 1.0001102  0.99996138]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00109869 1.0025911  1.00049678 1.00077276 1.00010715 0.99993468]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00115259 1.00262946 1.00034133 1.00080409 1.00010422 0.99993088]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00127845 1.00281616 1.00038356 1.00059816 1.0001005  0.99986945]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0011254  1.00262719 1.0002004  1.00056719 1.00009848 0.99987898]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00099426 1.00242893 1.00016351 1.00060129 1.00009719 0.99991885]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00101489 1.00197585 1.0000576  1.00054813 1.00009662 0.99999188]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00087976 1.00170084 1.00004703 1.00072957 0.99995979 0.99995993]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00086134 1.00146132 0.99998243 1.00067182 0.99996077 0.99994085]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00057527 1.0012508  0.99994763 1.00072682 0.9999616  0.99991802]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032715 1.00090524 0.99987421 1.00067161 0.99996228 0.99993101]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038736 1.00085228 0.99986412 1.00054784 0.99996311 0.99992404]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00041832 1.00090994 0.99989947 1.00056377 0.99996379 0.99992774]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030511 1.001113   0.99991552 1.00042895 0.99996442 0.99991721]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp= False, type_source="BH")
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_BH_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Cir X-1: No saved LrLx data
# GRS 1915+105: No saved LrLx data
# Swift J1728.9-3613: No saved LrLx data
# Swift J1858.6-0814: No saved LrLx data
# Sources included after filtering:  ['4U 1543-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070' 'Swift J1727.8-1613']
# Number of source: 12
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.145  -0.039  +0.039
# Beta  = 0.577  -0.028  +0.028
# Sigma = 0.460  -0.029  +0.029
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.145  -0.039  +0.039
# Beta  = 0.577  -0.028  +0.027
# Sigma = 0.459  -0.028  +0.030
# The 90% lower limit on beta from all values
# Beta > 0.541
# The 90% upper limit on beta from all values
# Beta < 0.613
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.145  -0.039  +0.039
# Beta =  0.577  -0.028  +0.027
# Sigma =  0.459  -0.028  +0.030
# The 90% lower limit on beta from run results
# Beta >  0.54
# The 90% upper limit on beta from run results
# Beta <  0.61

# %% [markdown]
# ---

# %% [markdown]
# ###
