# %% [markdown]
# # IGR J1701

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["IGR J17091-3624"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['IGR J17091-3624']
# Sources included after filtering:  ['IGR J17091-3624']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['IGR J17091-3624']_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99416087 0.99448544 1.01546364 1.32332115 1.00183697 1.02397926]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99661954 0.99675223 1.00820318 1.09548995 0.99997419 1.00228797]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00183547 1.00195098 0.99987437 1.06731156 1.00020784 0.99877726]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# ...

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["IGR J17091-3624"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['IGR J17091-3624']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['IGR J17091-3624']
# Sources included after filtering:  ['IGR J17091-3624']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -1.922  -1.854  +1.694
# Beta  = 1.439  -0.884  +0.962
# Sigma = 1.042  -0.899  +0.133
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -1.959  -1.817  +1.731
# Beta  = 1.458  -0.903  +0.943
# Sigma = 0.329  -0.186  +0.845
# The 90% lower limit on beta from all values
# Beta > -0.085
# The 90% upper limit on beta from all values
# Beta < 3.036
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -1.959  -1.817  +1.731
# ...
