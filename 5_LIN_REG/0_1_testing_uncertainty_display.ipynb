# %% [markdown]
# In this notebook. we test the different ways of showing the uncertainties on the plots.

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %%
linmix_results(N_runs=100, interp= True, type_source="BH", show_alt_uncertainty_methods=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_BH_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['4U 1543-47' '4U 1630-47' 'EXO 1846-031' 'GRS 1739-278' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298' 'MAXI J1810-222' 'MAXI J1820+070'
#  'Swift J1727.8-1613' 'Swift J1842.5-1124']
# Number of source: 14
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# ...

# %%
linmix_results(N_runs=100, interp= True, type_source="NS", show_alt_uncertainty_methods=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_NS_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['1A 1744-361' '4U 1543-47' '4U 1630-47' 'Cen X-4' 'Cir X-1' 'EXO 1846-031' 'GRS 1739-278' 'GRS 1915+105' 'GX 339-4' 'H1743-322' 'IGR J17091-3624' 'MAXI J1348-630' 'MAXI J1631-479' 'MAXI J1803-298'
#  'MAXI J1807+132' 'MAXI J1810-222' 'MAXI J1816-195' 'MAXI J1820+070' 'SAX J1808.4-3658' 'SAX J1810.8-2609' 'Swift J1727.8-1613' 'Swift J1728.9-3613' 'Swift J1842.5-1124' 'Swift J1858.6-0814'
#  'XTE J1701-462']
# Sources included after filtering:  ['1A 1744-361' 'Cen X-4' 'MAXI J1807+132' 'MAXI J1816-195' 'SAX J1808.4-3658' 'SAX J1810.8-2609']
# Number of source: 6
# (1507400,) (1507400,) (1507400,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -2.932  -1.028  +1.015
# Beta  = 1.089  -0.595  +0.610
# Sigma = 1.987  -0.963  +0.972
# ...

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["MAXI J1820+070"], show_alt_uncertainty_methods=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.019  -0.030  +0.030
# Beta  = 0.505  -0.023  +0.023
# Sigma = 0.130  -0.019  +0.019
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.018  -0.030  +0.030
# Beta  = 0.505  -0.022  +0.023
# Sigma = 0.128  -0.017  +0.021
# The 90% lower limit on beta from all values
# Beta > 0.476
# The 90% upper limit on beta from all values
# Beta < 0.534
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.018  -0.030  +0.030
# Beta =  0.505  -0.022  +0.023
# ...

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["MAXI J1820+070"], show_alt_uncertainty_methods=True, plot_unc=False)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.019  -0.030  +0.030
# Beta  = 0.505  -0.023  +0.023
# Sigma = 0.130  -0.019  +0.019
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.018  -0.030  +0.030
# Beta  = 0.505  -0.022  +0.023
# Sigma = 0.128  -0.017  +0.021
# The 90% lower limit on beta from all values
# Beta > 0.476
# The 90% upper limit on beta from all values
# Beta < 0.534
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.018  -0.030  +0.030
# Beta =  0.505  -0.022  +0.023
# ...

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["4U 1543-47"], show_alt_uncertainty_methods=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['4U 1543-47']
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.713  -0.079  +0.078
# Beta  = 0.902  -0.129  +0.130
# Sigma = 0.253  -0.063  +0.060
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.714  -0.080  +0.077
# Beta  = 0.902  -0.128  +0.130
# Sigma = 0.241  -0.051  +0.072
# The 90% lower limit on beta from all values
# Beta > 0.736
# The 90% upper limit on beta from all values
# Beta < 1.070
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.714  -0.080  +0.077
# Beta =  0.902  -0.128  +0.130
# ...

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["4U 1543-47"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['4U 1543-47']
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.713  -0.079  +0.078
# Beta  = 0.902  -0.129  +0.130
# Sigma = 0.253  -0.063  +0.060
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.714  -0.080  +0.077
# Beta  = 0.902  -0.128  +0.130
# Sigma = 0.241  -0.051  +0.072
# The 90% lower limit on beta from all values
# Beta > 0.736
# The 90% upper limit on beta from all values
# Beta < 1.070
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.714  -0.080  +0.077
# Beta =  0.902  -0.128  +0.130
# ...

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# False
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.439  -0.029  +0.028
# Beta  = 0.619  -0.025  +0.025
# Sigma = 0.270  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.440  -0.030  +0.027
# Beta  = 0.618  -0.024  +0.026
# Sigma = 0.269  -0.022  +0.024
# The 90% lower limit on beta from all values
# Beta > 0.587
# The 90% upper limit on beta from all values
# Beta < 0.652
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.440  -0.030  +0.027
# Beta =  0.618  -0.024  +0.026
# ...
