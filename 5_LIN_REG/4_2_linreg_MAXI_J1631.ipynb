# %% [markdown]
# # MAXI J1631-479

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["MAXI J1631-479"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.03734769 1.04979989 1.00854672 1.0258221  0.99962304 1.00404032]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01390088 1.01228542 1.00060663 1.03743676 1.00914748 1.00423932]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00271389 1.00431037 1.00900452 1.01771782 0.99934564 1.00060942]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007575 1.00273493 1.0097422  1.00541843 0.99951008 0.99996979]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045312 1.00342964 1.00531636 1.00422217 0.99947227 0.99937608]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006885 1.00543773 1.00270145 1.00086383 0.99955693 1.00060661]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996023 1.00370744 1.00016732 1.00164624 0.99959107 0.99986172]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00036596 1.00466034 1.0008498  1.00193171 0.99979151 1.00106062]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00094545 1.00304749 1.00125003 1.00035094 0.99981435 1.00047614]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00116991 1.00327178 0.99997576 0.99964401 0.99980818 1.00089149]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00057368 1.00285339 1.00028615 0.99956144 0.99979727 1.00059034]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069756 1.00269654 1.00044555 0.99960852 0.99981366 1.00136358]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030744 1.00207725 1.00075761 0.99965725 0.99980628 1.00183861]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00047977 1.00251218 1.00077482 1.00045215 0.99980035 1.00185517]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023992 1.0018201  1.00043611 1.00012969 0.99981357 1.00135545]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001406  1.00178076 1.00022783 0.99973945 0.99982309 1.00175576]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027042 1.00123212 1.00015562 0.99975504 0.99983622 1.0015703 ]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00076377 1.00172992 0.99994381 1.00006287 0.99985476 1.0012255 ]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00044484 1.00148581 1.00018892 1.00102592 0.99983513 1.00185312]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00064578 1.00176547 1.00020103 1.00115261 0.9998434  1.00158552]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00054057 1.00125941 1.00089236 1.00083031 0.99991637 1.00143468]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00047592 1.00116224 1.00080818 1.00095564 0.99991739 1.00127501]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00047126 1.00102365 1.00067256 1.00156013 0.99992122 1.00124858]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00068943 1.00119654 1.00074557 1.00191037 0.99992009 1.00143073]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00057005 1.0009844  1.00071714 1.00180367 0.99992638 1.00145733]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00052348 1.00092111 1.00077487 1.00157391 0.99992377 1.00121471]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046168 1.00100599 1.00075244 1.00140116 0.99992655 1.00123479]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039789 1.00067615 1.00065067 1.00142752 0.9999291  1.00111021]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00028437 1.00052929 1.00049518 1.00126595 0.99993903 1.000985  ]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00041152 1.0006015  1.00026681 1.00107242 0.99994106 1.00082567]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035306 1.00045463 1.00015694 1.0007182  0.99994295 1.00074819]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00047684 1.00052649 1.00024086 1.00073873 0.99994374 1.00061601]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030662 1.00031226 1.00028668 1.00059459 0.99994541 1.00051768]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00029929 1.00032711 1.00036902 1.0003981  0.99995281 1.00024528]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011249 1.00017763 1.00001965 0.99998301 0.99995423 0.99995584]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001286 1.00009547 1.00001031 1.0000698  0.99995328 1.00005288]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009841 1.00017295 0.99999245 1.00020823 0.99995447 1.00020344]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013057 1.0002014  1.00008838 1.00017949 0.99995564 1.00014682]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011085 1.000192   1.00003012 1.00015343 0.99995666 1.00009758]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015417 1.00019853 0.99997707 1.00022419 0.99995309 1.00001177]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007082 1.00009457 0.99989706 1.00030595 0.99995426 0.9998586 ]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011671 1.00011716 0.99987383 1.0002248  0.99995481 0.99990518]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015869 1.00010418 0.99991255 1.0001527  0.99995292 1.00001632]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012077 1.00011729 0.99999268 1.00032929 0.99995396 1.00008306]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0000548  1.00011793 1.00016599 1.00046753 0.99995493 1.00018728]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000682 1.0000771  1.00005085 1.00041225 0.99995591 1.00017763]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001856 1.00006751 1.00010041 1.00028574 0.99995681 1.00039176]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006548 1.00008392 1.00002845 1.00033313 0.99995768 1.00033753]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012576 1.0001217  0.99999156 1.00034141 0.99995848 1.0002609 ]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004257 1.00008134 1.00000054 1.00029847 0.99995961 1.00024501]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["MAXI J1631-479"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.152  -0.059  +0.059
# Beta  = 0.195  -0.034  +0.034
# Sigma = 0.127  -0.046  +0.043
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.154  -0.060  +0.057
# Beta  = 0.195  -0.033  +0.034
# Sigma = 0.114  -0.033  +0.056
# The 90% lower limit on beta from all values
# Beta > 0.150
# The 90% upper limit on beta from all values
# Beta < 0.242
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.154  -0.060  +0.057
# Beta =  0.195  -0.033  +0.034
# Sigma =  0.114  -0.033  +0.056
# The 90% lower limit on beta from run results
# Beta >  0.15
# The 90% upper limit on beta from run results
# Beta <  0.24

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, seed=5, interp=True, type_source=None, names = ["MAXI J1631-479"], parallel=True, verbose=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_100
# 100%|██████████| 100/100 [02:11<00:00,  1.32s/it]

# %%
linmix_results(N_runs=100, interp=True, type_source=None, names=["MAXI J1631-479"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.147  -0.114  +0.112
# Beta  = 0.195  -0.034  +0.034
# Sigma = 0.127  -0.047  +0.044
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.148  -0.115  +0.111
# Beta  = 0.194  -0.034  +0.035
# Sigma = 0.114  -0.034  +0.057
# The 90% lower limit on beta from all values
# Beta > 0.149
# The 90% upper limit on beta from all values
# Beta < 0.241
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.148  -0.061  +0.058
# Beta =  0.194  -0.034  +0.035
# Sigma =  0.114  -0.034  +0.057
# The 90% lower limit on beta from run results
# Beta >  0.15
# The 90% upper limit on beta from run results
# Beta <  0.24

# %% [markdown]
# ---

# %% [markdown]
# # Using Paired Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=False, type_source=None, names = ["MAXI J1631-479"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_paired_['MAXI J1631-479']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99580078 0.99617046 1.02608985 1.01634233 1.00611062 1.05324925]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99689184 0.99573114 1.00718254 1.00004556 0.99906738 1.00632337]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99699724 0.99679324 1.00425757 0.99922335 0.99833166 1.0008954 ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99792081 0.99764477 1.0057826  1.00146497 0.99975339 0.99900082]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99906695 0.99819771 1.00155525 1.00175764 0.99979301 0.99853399]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99863494 0.99859686 1.00082512 1.00049078 0.99980066 1.00039518]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971838 0.99959049 1.00056291 1.00234638 0.9998228  1.00265234]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997809  0.99969893 1.00159117 1.00611291 0.99954405 1.00117925]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99931903 0.99949476 1.00217258 1.00381667 0.99960185 1.00169968]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99928462 0.99944627 1.00200815 1.00892354 0.9997537  1.00083027]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99938108 0.99929034 1.00259828 1.00589483 0.99976762 1.00221578]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99958355 0.99923976 1.00183262 1.00696453 0.99979271 1.00186982]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99941565 0.99925458 1.0011382  1.00600574 0.99978975 1.00167667]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99946812 0.99934448 1.00100247 1.00347779 0.99986361 1.00160195]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987984 0.99957125 0.99967857 1.00181329 0.99990427 1.00029115]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993505 0.99947889 0.99972686 1.00205817 0.99991406 0.99986654]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013299 0.99952348 0.9998287  1.00176904 0.99994751 0.99993691]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00059944 0.99978488 1.00037821 1.00192793 0.99994494 0.99986244]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018426 0.99975169 1.00076871 1.0019058  0.9999422  1.00022929]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014539 0.9999175  1.00113255 1.00209361 0.99994641 1.00037917]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038128 1.00002097 1.00125376 1.00174708 0.99994617 0.99984563]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0005606  1.00004995 1.00136778 1.00151005 0.99983413 1.00001521]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039402 1.00004279 1.00118556 1.00195873 1.00024234 1.00014895]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010482 0.99986088 1.00123383 1.0023901  1.00023125 1.00034123]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015213 0.99996921 1.00150301 1.00197531 1.00021385 1.0002382 ]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010737 0.99995515 1.00170241 1.00149448 1.00020005 1.00011216]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00019077 1.00011646 1.00104593 1.001624   1.00019111 1.00012111]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018574 1.00001207 1.00093054 1.00208896 1.00018622 1.00004505]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017803 1.00007738 1.0008073  1.00206508 1.00017973 1.0000351 ]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014601 1.00011626 1.00060631 1.00218607 1.00017432 0.99983765]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013667 1.00011721 1.00058789 1.00203679 1.00016505 0.99999294]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010354 1.00002849 1.00052484 1.00211783 1.00015961 1.00012097]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993441 0.9999154  1.00056821 1.0014155  1.00014675 1.00007494]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987134 0.99990178 1.00071187 1.00143418 1.00013803 1.00013484]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987822 0.99991619 1.00091736 1.00144373 1.000134   1.00042569]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998064  0.99994433 1.00115183 1.00115067 1.00012968 1.00055431]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982892 0.99998201 1.00130105 1.0011691  1.00012451 1.00065245]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988511 1.00009504 1.00108143 1.00063128 1.00012049 1.00085818]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996375 1.00017306 1.00077374 1.00053666 1.00015583 1.00069989]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990426 1.00007574 1.00065182 1.00062053 1.00014646 1.00060658]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992715 1.00006883 1.00069893 1.00075829 1.00014634 1.00072737]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999277 1.0001028  1.00063942 1.00075843 1.00014249 1.00072215]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005636 1.00020493 1.00068497 1.00051394 1.00013863 1.00079653]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006426 1.00025736 1.00075467 1.00027034 1.00010182 1.00081074]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999642  1.00017253 1.00047079 1.00010759 1.0000973  1.00052944]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995592 1.00011181 1.00026705 1.00022966 1.00009348 1.0002161 ]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995518 1.00010778 1.00019209 1.00007939 1.00008286 1.00024218]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996837 1.00013195 1.00013045 1.00016002 1.00005996 1.00025382]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998219 1.00014756 1.00011809 1.00011947 1.0000866  1.0001956 ]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003537 1.00015811 1.0000255  1.00017342 1.00008248 1.00016675]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=False, type_source=None, names=["MAXI J1631-479"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_['MAXI J1631-479']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.334  -0.076  +0.075
# Beta  = 0.196  -0.042  +0.042
# Sigma = 0.150  -0.059  +0.054
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.336  -0.078  +0.073
# Beta  = 0.195  -0.041  +0.042
# Sigma = 0.131  -0.041  +0.073
# The 90% lower limit on beta from all values
# Beta > 0.140
# The 90% upper limit on beta from all values
# Beta < 0.253
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.336  -0.078  +0.073
# Beta =  0.195  -0.041  +0.042
# Sigma =  0.131  -0.041  +0.073
# The 90% lower limit on beta from run results
# Beta >  0.14
# The 90% upper limit on beta from run results
# Beta <  0.25
