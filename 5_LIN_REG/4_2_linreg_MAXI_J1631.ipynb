# %% [markdown]
# # MAXI J1631-479

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["MAXI J1631-479"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99734652 0.99533614 1.01720819 1.0071852  1.01354976 1.00096389]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996607 0.99624933 1.0110143  1.00363832 1.01380947 1.00219972]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0008646  0.99690184 1.0083587  1.00072595 1.00096111 1.00825751]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00091533 0.99798621 1.00760288 1.00108561 1.0006621  1.00070849]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00131126 0.99931794 1.01163597 1.00213533 0.99944774 1.00083011]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00245308 1.0002115  1.01226474 1.00612791 0.99992583 1.00595734]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00084632 0.99976485 1.0103779  1.00199762 0.99976456 1.01294754]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00067223 1.0002876  1.00479822 1.00251782 0.99977632 1.00860577]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971184 0.99970846 1.00512231 1.004174   0.99957778 1.00803663]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9995415  0.99992741 1.00508712 1.00153614 0.99976896 1.00801121]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99952055 0.99998339 1.0052265  1.00188456 0.999823   1.00984785]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017958 1.00053489 1.00448452 1.00284511 0.99999872 1.00778347]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000446   1.00073767 1.00287283 1.00296323 0.99998376 1.00613312]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000799 1.00054225 1.00214283 1.00161311 0.99989826 1.00389942]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038886 1.00065453 1.00263609 1.00096441 0.99957465 1.00400953]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032093 1.00054238 1.00310088 1.00057636 0.99962761 1.00451269]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00022306 1.00059046 1.00300656 1.0003808  0.99965295 1.00421718]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0000262  1.00039338 1.00273962 1.00024321 0.99967414 1.00335111]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00044641 1.00060522 1.00322107 1.00080958 0.9996972  1.00278697]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027363 1.00025234 1.00393543 1.00077623 0.99974067 1.00281948]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00040816 1.00023712 1.00376821 1.00091688 1.00001947 1.00234444]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00057351 1.00035343 1.0039496  1.00091048 1.00003046 1.00204264]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035816 1.00020369 1.0034846  1.001584   1.00002374 1.00175483]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002038  0.99995643 1.00292261 1.00180847 1.00002286 1.00159067]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015349 1.00003195 1.00206777 1.0016091  1.00002187 1.00116868]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035254 1.00013136 1.00156188 1.00179857 1.00002051 1.00037447]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00050111 1.00031429 1.00141981 1.00186754 1.00001643 1.00007274]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048961 1.0002315  1.00162457 1.00153725 1.00001657 1.00021756]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023024 1.00004415 1.0017404  1.00151686 1.00001625 1.00039977]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00019367 1.00003225 1.00150352 1.00166168 1.00003039 1.00070076]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001528  0.99995348 1.00192641 1.00158195 1.000031   1.00115962]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999511 0.99985217 1.001723   1.00162878 1.00003006 1.00116117]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993503 0.99979102 1.00179478 1.00120997 1.00002894 1.00119838]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004487 0.99982555 1.00154049 1.00123372 1.00002585 1.00101603]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000044   0.99984958 1.00123355 1.00129687 1.00002515 1.00086835]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005517 0.9998639  1.00113147 1.0010638  1.00001714 1.00060266]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006041 0.99995859 1.00128352 1.00084358 1.00008391 1.00050772]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011264 0.99995373 1.00140081 1.00128546 0.99998445 1.00052703]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014056 0.99995994 1.00116909 1.0014108  0.99998503 1.00039091]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016787 0.99992348 1.00129436 1.00080439 0.99998521 1.00050543]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021655 0.99998016 1.00114036 1.00086794 0.9999855  1.00036766]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012864 0.99997108 1.00106164 1.00146223 0.99998731 1.000227  ]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009344 0.99993631 1.00094229 1.00145511 0.99998859 1.00026016]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004266 0.99990824 1.00089162 1.00167918 0.99998834 1.00015609]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016916 0.99997877 1.0009686  1.00168751 0.9999886  1.00028043]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001555  0.9999652  1.00097671 1.00151848 0.9999886  1.00025383]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017991 0.99997961 1.00111337 1.00134761 0.99998882 1.00044224]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012499 0.99998381 1.00119484 1.0013543  0.9999889  1.00047641]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012651 1.00005048 1.0011272  1.00137199 0.99998979 1.00041972]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008622 1.0000467  1.00131314 1.00141254 0.99998978 1.00054649]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["MAXI J1631-479"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.337  -0.066  +0.064
# Beta  = 0.194  -0.034  +0.034
# Sigma = 0.126  -0.046  +0.043
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.338  -0.067  +0.063
# Beta  = 0.195  -0.034  +0.034
# Sigma = 0.113  -0.033  +0.056
# The 90% lower limit on beta from all values
# Beta > 0.149
# The 90% upper limit on beta from all values
# Beta < 0.240
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.338  -0.067  +0.063
# Beta =  0.195  -0.034  +0.034
# Sigma =  0.113  -0.033  +0.056
# The 90% lower limit on beta from run results
# Beta >  0.15
# The 90% upper limit on beta from run results
# Beta <  0.24

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, seed=5, interp=True, type_source=None, names = ["MAXI J1631-479"], parallel=True, verbose=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_100
# 100%|██████████| 100/100 [01:58<00:00,  1.19s/it]

# %%
linmix_results(N_runs=100, interp=True, type_source=None, names=["MAXI J1631-479"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1631-479']_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.322  -0.169  +0.163
# Beta  = 0.195  -0.034  +0.034
# Sigma = 0.128  -0.047  +0.044
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.328  -0.175  +0.156
# Beta  = 0.194  -0.034  +0.035
# Sigma = 0.114  -0.034  +0.057
# The 90% lower limit on beta from all values
# Beta > 0.149
# The 90% upper limit on beta from all values
# Beta < 0.241
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.323  -0.066  +0.064
# Beta =  0.194  -0.034  +0.035
# Sigma =  0.114  -0.034  +0.057
# The 90% lower limit on beta from run results
# Beta >  0.15
# The 90% upper limit on beta from run results
# Beta <  0.24

# %% [markdown]
# ---

# %% [markdown]
# # Using Paired Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=False, type_source=None, names = ["MAXI J1631-479"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_paired_['MAXI J1631-479']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99580078 0.99617046 1.02608985 1.01634233 1.00611062 1.05324925]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99689184 0.99573114 1.00718254 1.00004556 0.99906738 1.00632337]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99699724 0.99679324 1.00425757 0.99922335 0.99833166 1.0008954 ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99792081 0.99764477 1.0057826  1.00146497 0.99975339 0.99900082]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99906695 0.99819771 1.00155525 1.00175764 0.99979301 0.99853399]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99863494 0.99859686 1.00082512 1.00049078 0.99980066 1.00039518]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971838 0.99959049 1.00056291 1.00234638 0.9998228  1.00265234]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997809  0.99969893 1.00159117 1.00611291 0.99954405 1.00117925]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99931903 0.99949476 1.00217258 1.00381667 0.99960185 1.00169968]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99928462 0.99944627 1.00200815 1.00892354 0.9997537  1.00083027]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99938108 0.99929034 1.00259828 1.00589483 0.99976762 1.00221578]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99958355 0.99923976 1.00183262 1.00696453 0.99979271 1.00186982]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99941565 0.99925458 1.0011382  1.00600574 0.99978975 1.00167667]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99946812 0.99934448 1.00100247 1.00347779 0.99986361 1.00160195]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987984 0.99957125 0.99967857 1.00181329 0.99990427 1.00029115]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993505 0.99947889 0.99972686 1.00205817 0.99991406 0.99986654]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013299 0.99952348 0.9998287  1.00176904 0.99994751 0.99993691]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00059944 0.99978488 1.00037821 1.00192793 0.99994494 0.99986244]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018426 0.99975169 1.00076871 1.0019058  0.9999422  1.00022929]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014539 0.9999175  1.00113255 1.00209361 0.99994641 1.00037917]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038128 1.00002097 1.00125376 1.00174708 0.99994617 0.99984563]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0005606  1.00004995 1.00136778 1.00151005 0.99983413 1.00001521]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039402 1.00004279 1.00118556 1.00195873 1.00024234 1.00014895]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010482 0.99986088 1.00123383 1.0023901  1.00023125 1.00034123]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015213 0.99996921 1.00150301 1.00197531 1.00021385 1.0002382 ]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010737 0.99995515 1.00170241 1.00149448 1.00020005 1.00011216]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00019077 1.00011646 1.00104593 1.001624   1.00019111 1.00012111]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018574 1.00001207 1.00093054 1.00208896 1.00018622 1.00004505]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017803 1.00007738 1.0008073  1.00206508 1.00017973 1.0000351 ]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014601 1.00011626 1.00060631 1.00218607 1.00017432 0.99983765]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013667 1.00011721 1.00058789 1.00203679 1.00016505 0.99999294]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010354 1.00002849 1.00052484 1.00211783 1.00015961 1.00012097]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993441 0.9999154  1.00056821 1.0014155  1.00014675 1.00007494]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987134 0.99990178 1.00071187 1.00143418 1.00013803 1.00013484]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987822 0.99991619 1.00091736 1.00144373 1.000134   1.00042569]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998064  0.99994433 1.00115183 1.00115067 1.00012968 1.00055431]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982892 0.99998201 1.00130105 1.0011691  1.00012451 1.00065245]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988511 1.00009504 1.00108143 1.00063128 1.00012049 1.00085818]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996375 1.00017306 1.00077374 1.00053666 1.00015583 1.00069989]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990426 1.00007574 1.00065182 1.00062053 1.00014646 1.00060658]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992715 1.00006883 1.00069893 1.00075829 1.00014634 1.00072737]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999277 1.0001028  1.00063942 1.00075843 1.00014249 1.00072215]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005636 1.00020493 1.00068497 1.00051394 1.00013863 1.00079653]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006426 1.00025736 1.00075467 1.00027034 1.00010182 1.00081074]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999642  1.00017253 1.00047079 1.00010759 1.0000973  1.00052944]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995592 1.00011181 1.00026705 1.00022966 1.00009348 1.0002161 ]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995518 1.00010778 1.00019209 1.00007939 1.00008286 1.00024218]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996837 1.00013195 1.00013045 1.00016002 1.00005996 1.00025382]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998219 1.00014756 1.00011809 1.00011947 1.0000866  1.0001956 ]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003537 1.00015811 1.0000255  1.00017342 1.00008248 1.00016675]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=False, type_source=None, names=["MAXI J1631-479"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_['MAXI J1631-479']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1631-479']
# Sources included after filtering:  ['MAXI J1631-479']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.334  -0.076  +0.075
# Beta  = 0.196  -0.042  +0.042
# Sigma = 0.150  -0.059  +0.054
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.336  -0.078  +0.073
# Beta  = 0.195  -0.041  +0.042
# Sigma = 0.131  -0.041  +0.073
# The 90% lower limit on beta from all values
# Beta > 0.140
# The 90% upper limit on beta from all values
# Beta < 0.253
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.336  -0.078  +0.073
# Beta =  0.195  -0.041  +0.042
# Sigma =  0.131  -0.041  +0.073
# The 90% lower limit on beta from run results
# Beta >  0.14
# The 90% upper limit on beta from run results
# Beta <  0.25
