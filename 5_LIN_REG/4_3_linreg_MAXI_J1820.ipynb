# %% [markdown]
# # MAXI J1820

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["MAXI J1820+070"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99366311 0.99755718 1.03969357 0.99797055 1.00667832 1.01891513]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99620313 0.9984262  1.02214355 1.0197511  1.00411474 1.00529538]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99920249 0.99962815 1.00827752 1.00857906 1.00274112 1.00539223]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99939208 1.00120454 1.00265078 1.00238267 1.00218191 1.00633834]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976268 1.00163941 1.0003536  1.0003338  0.99904611 1.00221819]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99889602 1.00176702 1.00144352 1.000276   0.9991679  1.00320781]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99951512 1.00181866 1.00103172 0.99897471 0.99931024 1.00237933]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99920866 1.0011747  1.00068197 0.99885441 0.99920141 1.00072584]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99918023 0.99951338 1.00030289 0.99903298 0.99927939 1.00021517]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.999264   0.9998338  1.00103781 0.99938115 0.99935334 1.00073343]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99931544 1.00058149 1.00073535 0.999599   0.99939189 1.00063314]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99931948 1.00014508 0.99999226 0.99975594 0.99946006 1.00012039]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99950434 0.99938801 0.99948744 0.99986104 0.99942576 1.00029231]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974473 0.99970973 0.99959089 0.9995871  0.99948344 1.00023481]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998778 0.99978193 1.00002299 0.99971949 0.99951182 1.00059778]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001939 0.99976934 0.99981576 0.99979045 0.9995468  1.00055013]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99970727 0.99958419 1.00009818 0.99974967 0.99957174 1.00081   ]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99966679 0.99955942 0.99987498 0.99963935 0.99962987 1.00045707]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978864 0.99971001 0.99979202 0.99976019 0.99965267 1.00038704]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010943 0.99981848 0.99991236 0.99983993 0.99966638 1.00032942]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017201 0.9998655  0.99986804 0.99988304 0.99966537 1.0001523 ]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017978 1.00000328 0.99981264 0.99984746 0.99968249 1.00014959]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018238 1.00035157 0.9999157  0.99982979 0.99969671 1.0000259 ]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00029986 1.00021061 0.99987913 0.99975098 0.99970883 1.00010625]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027437 1.00036253 1.00004467 0.99971286 0.99971729 1.00013983]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000761 1.00027677 1.00024029 0.9997086  0.99983986 1.00024032]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003553 1.00033087 1.00016669 0.99966206 0.99984539 1.00010532]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009664 1.00040214 1.00027127 0.99967148 0.99984407 1.00015529]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009022 1.00042197 1.00039448 0.99974592 0.99984972 1.00008669]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004864 1.00041046 1.00067105 0.99973023 0.99982889 1.00009925]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001839  1.00036061 1.00055254 0.9997593  0.99983363 1.00009404]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010919 1.00053595 1.00051615 0.99983298 0.9998192  1.00001805]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007593 1.00048426 1.00028021 0.99991388 0.99982533 1.00000018]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013807 1.00049893 1.00017419 1.00003645 0.99982943 0.99999677]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010906 1.00053085 1.00047887 1.00009883 0.9998472  0.99997483]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001415 1.0004652  1.00051246 1.00015165 0.9998513  0.9999424 ]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0000199  1.00062305 1.0005379  1.0001845  0.99985387 0.99994258]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004294 1.0005237  1.00053612 1.00019751 0.9998815  0.99992861]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005818 1.00037684 1.00039293 1.00022714 0.99988558 0.99997432]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001351 1.00034018 1.00055281 1.00025734 0.99988974 1.00004269]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008242 1.00036449 1.00054638 1.00016515 0.99989359 1.00004559]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013071 1.00034703 1.00038574 1.00012983 0.99989603 1.00003358]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001297  1.00028994 1.00029623 1.00012106 0.99989824 1.00000339]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007716 1.00038331 1.00029118 1.00018352 0.9999026  0.99994546]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009608 1.00032646 1.00036594 1.00020886 0.99990418 0.999946  ]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010613 1.00032052 1.00029461 1.00013176 0.99991184 1.00001915]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014423 1.00037198 1.00026649 1.00026889 0.99991877 1.00004321]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016155 1.00040224 1.00033069 1.00031642 0.99991967 1.00004247]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015036 1.0004567  1.00038514 1.00037904 0.99992206 1.00006611]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016496 1.00043286 1.00046715 1.00037074 0.99992501 1.00015511]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["MAXI J1820+070"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.019  -0.030  +0.030
# Beta  = 0.505  -0.023  +0.023
# Sigma = 0.130  -0.019  +0.019
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.018  -0.030  +0.030
# Beta  = 0.505  -0.022  +0.023
# Sigma = 0.128  -0.017  +0.021
# The 90% lower limit on beta from all values
# Beta > 0.476
# The 90% upper limit on beta from all values
# Beta < 0.534
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.018  -0.030  +0.030
# Beta =  0.505  -0.022  +0.023
# Sigma =  0.128  -0.017  +0.021
# The 90% lower limit on beta from run results
# Beta >  0.48
# The 90% upper limit on beta from run results
# Beta <  0.53

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, seed=5, interp=True, type_source=None, names = ["MAXI J1820+070"], parallel=True, verbose=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_100
# 100%|██████████| 100/100 [02:13<00:00,  1.34s/it]

# %%
linmix_results(N_runs=100, interp=True, type_source=None, names=["MAXI J1820+070"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['MAXI J1820+070']_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.025  -0.060  +0.062
# Beta  = 0.505  -0.023  +0.023
# Sigma = 0.130  -0.019  +0.019
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.020  -0.064  +0.057
# Beta  = 0.505  -0.022  +0.023
# Sigma = 0.129  -0.017  +0.020
# The 90% lower limit on beta from all values
# Beta > 0.476
# The 90% upper limit on beta from all values
# Beta < 0.534
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.025  -0.030  +0.030
# Beta =  0.505  -0.022  +0.023
# Sigma =  0.129  -0.017  +0.020
# The 90% lower limit on beta from run results
# Beta >  0.48
# The 90% upper limit on beta from run results
# Beta <  0.53

# %% [markdown]
# ---

# %% [markdown]
# # Using Paired Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=False, type_source=None, names = ["MAXI J1820+070"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_paired_['MAXI J1820+070']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99817458 1.00228656 1.01914362 0.99382878 1.01570852 1.02072405]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99842347 1.00220811 1.01620863 0.99619473 1.00451814 1.017982  ]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00186577 1.00382804 1.00781256 1.0009091  0.99914817 1.01008586]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00167056 1.0039111  1.00563338 1.00666193 1.00000321 1.00980087]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00357903 1.00323754 1.00387881 1.00268446 1.00000199 1.01132316]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99965454 1.00109767 1.00091865 1.00260674 1.00000177 1.00978335]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99947622 1.00182542 1.00273839 1.00135551 1.0000014  1.00666558]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99920449 1.00163019 1.00181202 1.00079572 1.00000047 1.00334769]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021505 1.00112967 1.00298536 1.00120857 1.00000019 1.00303856]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00068082 1.00090631 1.001341   1.00061773 0.99999989 1.00215686]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039858 1.00012019 1.00114307 1.00128445 0.99999992 1.0020593 ]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00052403 1.00008849 1.00138318 1.00120362 0.99999977 1.0014922 ]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00096982 1.00010324 1.00036683 1.0008447  0.99999292 1.00050173]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00097024 1.00002676 1.00036425 1.00019572 0.99999342 1.00060029]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00074938 0.99998922 1.00068282 1.00036705 0.9999938  1.00052672]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000458   0.99976124 1.00135678 1.0003515  0.99999418 1.00047499]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00055581 0.99999467 1.00103591 1.00020118 0.9999945  0.99999646]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00076774 1.00008085 1.00028684 1.00055078 0.9999948  1.00008333]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00081657 1.00028597 1.00038786 1.00036808 0.99999508 0.99992541]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00061712 1.00032364 1.00027067 1.0003537  0.99999532 0.99993853]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00071766 1.00056228 1.00037446 1.00039171 0.9999955  0.99973665]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0008697  1.00081397 1.00042805 1.00071428 0.99999571 0.99976747]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00064771 1.00043843 1.00056642 1.00136288 0.99999589 0.99969462]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00067416 1.00043031 1.00036124 1.00136904 0.99999607 0.99961447]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00066992 1.00055037 1.0003091  1.00088385 0.99999623 0.99964992]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058106 1.0003601  1.00038852 1.00058026 0.99999637 0.99964524]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00047556 1.00034807 1.00041337 1.00030392 0.99999651 0.99975637]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00063366 1.00042445 1.00051044 1.00026915 0.99999663 0.99974181]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035657 1.00016084 1.00031567 1.00004146 0.99999675 0.99976152]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00028283 1.0000726  1.0003764  1.00014534 0.99999686 0.99977466]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015359 1.00008544 1.00033507 1.00022125 0.99999697 0.99969341]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005147 1.00014403 1.00028881 1.00023139 0.99999706 0.99971789]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011716 1.00022237 1.00029491 1.00008938 0.99999715 0.99975651]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011868 1.00019924 1.00049387 1.00010321 0.99999724 0.99974796]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008805 1.00017336 1.00049289 1.00003891 0.99999731 0.99975183]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000171   1.0001083  1.00063534 1.00006023 0.99999739 0.99978673]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00014107 1.00016331 1.00058387 1.00012404 0.99999738 0.99979521]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013302 1.0000783  1.00062539 1.0000622  0.99999745 0.99983621]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007279 0.9999634  1.00056984 1.00012846 0.99999751 0.99984759]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998693 1.00002121 1.00048223 1.00021055 0.99999758 0.99986749]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992362 0.99997424 1.00046974 1.00020582 0.99999764 0.99989663]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988489 1.00005714 1.00057535 1.00038157 0.99999769 0.99992142]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985927 1.00010543 1.00050047 1.00029896 0.99999775 0.9999397 ]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983718 1.00006219 1.00040606 1.00023402 0.9999978  0.99988958]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983215 1.00007713 1.0006196  1.00024277 0.99999785 0.99986381]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980237 0.99998157 1.00053828 1.00015325 0.99999789 0.99990051]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980118 1.00001756 1.00057077 1.00018978 0.99999794 0.99987122]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980942 1.00001655 1.00061927 1.00010637 0.99999798 0.9998424 ]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982069 1.00006891 1.00069039 1.0000108  0.99999802 0.99988133]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981779 1.0000236  1.00072885 1.00001699 0.99999806 0.99989284]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=False, type_source=None, names=["MAXI J1820+070"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_['MAXI J1820+070']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['MAXI J1820+070']
# Sources included after filtering:  ['MAXI J1820+070']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = -0.006  -0.037  +0.037
# Beta  = 0.547  -0.031  +0.032
# Sigma = 0.142  -0.024  +0.024
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = -0.007  -0.036  +0.038
# Beta  = 0.546  -0.030  +0.032
# Sigma = 0.139  -0.022  +0.026
# The 90% lower limit on beta from all values
# Beta > 0.507
# The 90% upper limit on beta from all values
# Beta < 0.588
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  -0.007  -0.036  +0.038
# Beta =  0.546  -0.030  +0.032
# Sigma =  0.139  -0.022  +0.026
# The 90% lower limit on beta from run results
# Beta >  0.51
# The 90% upper limit on beta from run results
# Beta <  0.59
