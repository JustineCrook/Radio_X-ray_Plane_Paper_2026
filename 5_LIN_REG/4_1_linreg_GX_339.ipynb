# %% [markdown]
# # GX 339-4

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["GX 339-4"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009094 0.9974369  1.03312744 1.01731541 1.02528727 1.03391882]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00510723 1.01467307 1.00066812 1.01392902 0.99745151 0.99649616]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0047548  1.01148567 1.00418158 1.00889407 0.99943455 0.99974853]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99758283 1.00080363 0.99865983 1.00690478 0.99939819 0.99880014]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99919933 0.99911235 0.99950013 1.00290964 0.99945835 0.99899023]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00051363 0.99845898 1.00072662 1.00382865 0.99967687 0.9993862 ]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978186 0.9992817  1.00023737 1.00291119 0.99990046 0.99978831]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99909576 1.00019311 0.99988436 1.00532903 0.99928865 1.00017442]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99911933 1.00004932 1.00008747 1.00542027 0.99980587 1.00018343]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00083257 0.99972255 1.0011941  1.00421396 0.99992237 1.00046802]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046284 0.99972485 1.00021864 1.00386581 0.99978902 1.00018758]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027486 0.99954188 1.00003629 1.00336822 0.99972046 1.00026043]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00088829 1.00011316 1.00041532 1.00210554 0.99971837 1.00031616]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00107676 0.99976886 1.0011916  1.00106108 0.99978399 1.00099288]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0007466  1.0002135  1.00079617 1.00127158 0.99966232 1.00071772]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00041213 0.99971394 1.00135212 1.00146044 0.99955883 1.00061973]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998139  0.99961964 1.00130303 1.00141456 0.99980229 1.00052908]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982279 0.99946716 1.00093493 1.00134383 1.00053476 1.0007429 ]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999261 0.99984513 1.00123978 1.00128206 1.0005505  1.0009414 ]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004923 1.00009745 1.00141903 1.00084326 1.00068381 1.00132052]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0000666  0.99994279 1.00089602 1.00051816 1.00058027 1.00104586]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023436 1.0001254  1.00168938 1.00058331 1.00061902 1.00177146]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000209   1.00007686 1.00092819 1.00047966 1.00065063 1.00149742]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037919 1.00053088 1.0012588  1.00040272 1.000528   1.00166019]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00122211 1.00131536 1.00135612 1.00035119 1.00047622 1.00142121]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00089019 1.00132761 1.00097229 1.00038835 1.00036506 1.00109141]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00044162 1.00074153 1.00046057 1.00048284 1.00033422 1.00073819]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034785 1.00045991 1.00032168 1.00044343 1.00033907 1.00073231]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00042495 1.00064951 1.0000109  1.00039617 1.00030873 1.00035062]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00025277 1.00075745 0.99989361 1.0003668  1.00027292 1.00030076]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032759 1.00070674 0.99999404 1.00020998 1.00022203 1.0002692 ]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00053211 1.0007234  0.99999216 1.00015706 1.00028169 1.00028484]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058577 1.00081696 0.99997394 1.00013346 1.00034624 1.00022815]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00036758 1.00068012 0.99987282 1.00001747 1.00030821 1.00015125]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00026643 1.00054001 0.99992574 1.00011266 1.00038196 1.00022086]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000834 1.00024004 0.99991274 1.00018931 1.00033881 1.00025334]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009442 1.00028328 1.00002519 1.00031258 1.00027075 1.00013279]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011276 1.00025127 1.00002484 1.00032109 1.00024351 1.00020241]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00009995 1.0002493  1.0000025  1.00019064 1.00020471 1.00014987]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003713 1.00019094 1.00004883 1.00023509 1.00014206 1.0001706 ]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999314  1.00008761 1.00003936 1.00024072 1.00021084 1.00021199]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995474 1.00018129 1.0001273  1.00024061 1.00024727 1.00029585]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992748 1.00010883 1.00012048 1.00030723 1.00027431 1.00025332]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993035 1.00029474 1.00010897 1.00041532 1.00037158 1.00025006]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992964 1.00029189 1.00010456 1.00041782 1.00040235 1.00026052]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993988 1.00044855 1.00003115 1.00042217 1.00042435 1.00020141]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990931 1.00045041 1.00003556 1.00042828 1.00044698 1.00022597]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988559 1.00043606 1.00013019 1.00040355 1.00045479 1.00036001]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988016 1.00040986 1.00011852 1.00050014 1.00045251 1.00036119]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985611 1.00045252 1.00012776 1.00048976 1.00048301 1.00039154]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.439  -0.029  +0.028
# Beta  = 0.619  -0.025  +0.025
# Sigma = 0.270  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.440  -0.030  +0.027
# Beta  = 0.618  -0.024  +0.026
# Sigma = 0.269  -0.022  +0.024
# The 90% lower limit on beta from all values
# Beta > 0.587
# The 90% upper limit on beta from all values
# Beta < 0.652
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.440  -0.030  +0.027
# Beta =  0.618  -0.024  +0.026
# Sigma =  0.269  -0.022  +0.024
# The 90% lower limit on beta from run results
# Beta >  0.59
# The 90% upper limit on beta from run results
# Beta <  0.65

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.453  -0.028  +0.028
# Beta  = 0.611  -0.025  +0.024
# Sigma = 0.263  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.454  -0.029  +0.027
# Beta  = 0.611  -0.024  +0.025
# Sigma = 0.262  -0.022  +0.025
# The 90% lower limit on beta from all values
# Beta > 0.580
# The 90% upper limit on beta from all values
# Beta < 0.643
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.454  -0.029  +0.027
# Beta =  0.611  -0.024  +0.025
# Sigma =  0.262  -0.022  +0.025
# The 90% lower limit on beta from run results
# Beta >  0.58
# The 90% upper limit on beta from run results
# Beta <  0.64

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, seed=5, interp=True, type_source=None, names = ["GX 339-4"], parallel=True, verbose =True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_100
# 100%|██████████| 100/100 [04:51<00:00,  2.92s/it]

# %%
linmix_results(N_runs=100, interp=True, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.450  -0.053  +0.053
# Beta  = 0.611  -0.025  +0.024
# Sigma = 0.263  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.451  -0.054  +0.052
# Beta  = 0.611  -0.024  +0.025
# Sigma = 0.261  -0.022  +0.025
# The 90% lower limit on beta from all values
# Beta > 0.580
# The 90% upper limit on beta from all values
# Beta < 0.644
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.450  -0.028  +0.027
# Beta =  0.611  -0.024  +0.025
# Sigma =  0.261  -0.022  +0.025
# The 90% lower limit on beta from run results
# Beta >  0.58
# The 90% upper limit on beta from run results
# Beta <  0.64

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=False, type_source=None, names = ["GX 339-4"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_paired_['GX 339-4']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06365932 1.07831425 1.06840872 1.02330751 1.00302748 1.03548232]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00325442 1.01897661 1.01516494 1.0087423  1.00123301 1.01600813]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00627299 1.00862895 1.01063462 1.00300188 1.00203592 1.01808672]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01304668 1.02198294 1.02418781 1.00103123 1.00148494 1.01493953]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00980159 1.01114575 1.01745069 0.99972967 1.00116557 1.01394038]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00583534 1.0113596  1.01266069 0.99916458 1.00092292 1.01095496]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00517355 1.01012681 1.0089438  0.99879979 0.9999852  1.00507609]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00604953 1.01446246 1.0110832  0.99882148 0.9999889  1.00366237]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00319141 1.01016043 1.00516077 0.99965926 0.99999092 1.00221764]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991656 1.00409566 1.00103403 0.99940949 0.99999308 1.00087224]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997675 1.0022125  0.99974009 0.99947849 0.99999371 1.00036427]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039399 1.00289046 0.99997602 0.99958171 0.99999473 1.00044769]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00063511 1.00282021 1.00079004 0.99960977 0.99999174 1.00025331]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0009717  1.00300662 1.00014469 0.99950451 0.99999176 0.99996474]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069123 1.00211141 1.0006246  0.99969337 0.99999139 1.00000699]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0003957  1.00246786 1.00109107 0.99980393 0.99999126 1.00007519]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021979 1.00284584 1.0007204  0.99994844 0.9999922  1.00012924]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035734 1.0014375  1.00099242 0.99993704 0.9999045  1.00067235]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016916 1.00101886 1.00055959 0.99976754 0.99990817 1.00059714]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986695 1.00097124 1.00096433 0.99966166 0.99991296 1.00098107]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00033329 1.00187944 1.00222559 0.99965162 0.99991671 1.00147808]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00043708 1.00171178 1.00126464 0.99971725 0.99992045 1.0009189 ]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034407 1.00129601 1.00151913 0.99976324 0.99992243 1.00103772]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005767 1.00081185 1.00116021 0.99983428 0.99992579 1.00106153]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007972 1.00038495 1.00160042 0.99980855 0.99992853 1.00103844]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998611 1.00025991 1.00138553 0.99988072 0.99993137 1.00095003]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003796 1.00030277 1.00154413 0.99989972 0.99993375 1.00104045]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990637 1.00018606 1.00086239 0.99987649 0.9999363  1.00072031]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973616 0.99995536 1.00046586 0.99986743 0.99993829 1.00051752]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975125 0.99974025 1.00065828 0.99991408 0.99994028 1.00061223]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998425  1.00000731 1.00062539 0.99987619 0.99994228 1.00056083]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996912 1.00024029 1.00065695 0.99984527 0.99994389 1.0005406 ]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992648 1.00051405 1.00051475 0.99990638 0.99994565 1.00048195]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998228  1.0003768  1.00045339 0.99992633 0.99994717 1.00040809]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998695  1.00038539 1.00062767 0.99987462 0.9999484  1.00047414]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988282 1.00042896 1.00043032 0.99987725 0.99995003 1.00042711]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995663 1.00016105 1.00043139 0.99991587 0.99995126 1.00032013]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999776  1.00016417 1.00041636 0.9999449  0.99995243 1.00028511]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991809 1.00022237 1.00030883 0.99985774 0.99995356 1.00031103]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982894 1.00035506 1.00014834 0.99988224 0.99995484 1.00019192]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980147 1.00041195 1.00014602 0.99989353 0.99995603 1.00020171]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985063 1.00024748 1.00024717 0.99991817 0.999957   1.00030152]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989299 1.00027446 1.00040485 0.99995086 0.99995797 1.00036646]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000277 1.0002757  1.00064541 0.99991091 0.99995877 1.00055873]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032183 1.0002721  1.00098573 0.99993806 0.99995932 1.00056764]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046524 1.00062286 1.00129118 0.99995786 0.99995992 1.0005307 ]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048004 1.00052735 1.00108737 0.99991534 0.99996073 1.00045387]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045799 1.0006959  1.00119334 0.99995068 0.99996164 1.00053762]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00043903 1.00048219 1.00106307 0.99993957 0.99996188 1.00048417]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037274 1.00056668 1.0010292  0.99989269 0.99996269 1.00053741]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=False, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_['GX 339-4']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.471  -0.035  +0.035
# Beta  = 0.606  -0.031  +0.030
# Sigma = 0.275  -0.030  +0.030
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.471  -0.036  +0.034
# Beta  = 0.606  -0.030  +0.031
# Sigma = 0.272  -0.027  +0.032
# The 90% lower limit on beta from all values
# Beta > 0.567
# The 90% upper limit on beta from all values
# Beta < 0.646
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.471  -0.036  +0.034
# Beta =  0.606  -0.030  +0.031
# Sigma =  0.272  -0.027  +0.032
# The 90% lower limit on beta from run results
# Beta >  0.57
# The 90% upper limit on beta from run results
# Beta <  0.65

# %% [markdown]
# ---

# %% [markdown]
# # Excluding points with ejecta contamination

# %%
## Check data filtering

lr0, lx0, lr, dlr, delta_radio, lx, dlx_l, dlx_u, delta_xrays, source_names, unique_names, unique_D, unique_D_prob, t = get_data_arrays(names = ["GX 339-4"], interp=True, rerun = False, save=False, incl_Fr_uplims=True, type_source="BH")
delta = delta_radio.astype(int) # Convert boolean to int (1 for detection, 0 for upper limit)


# x:
lx_scaled = lx/lx0
log_lx_scaled = np.log10(lx_scaled) # x
log_dlx_l_scaled = np.log10(lx / (lx - dlx_l)) # = log(lx/lx0) - log( (lx - dlx_l)/ lx0 ) 
log_dlx_u_scaled = np.log10( ( lx + dlx_u) / lx ) # = log( (lx + dlx_u)/ lx0 ) - log(lx/lx0)
log_dlx_scaled = np.maximum(log_dlx_l_scaled , log_dlx_u_scaled )

# y:
lr_scaled = lr/lr0
log_lr_scaled = np.log10(lr_scaled) # y
log_dlr_l_scaled = np.log10(lr / (lr - dlr))
log_dlr_u_scaled = np.log10( ( lr + dlr) / lr )
log_dlr_scaled = np.maximum(log_dlr_l_scaled , log_dlr_u_scaled )

x = log_lx_scaled
y = log_lr_scaled
dx = log_dlx_scaled
dy = log_dlr_scaled
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1

# %%
## Filter for region of interest
"""
Previous filtering: 
t0 = 58964
t1 = 59083
gx339_mask = (lx > 2.7e34) & ( (t<t0) | (t>t1) )
mask_excl = (source_names=="GX 339-4") & ( (lx <= 2.7e34) | ( (t>=t0) & (t<=t1) ) )
"""

to_exclude = ((t >=58956) & (t <= 59080)) | (lx <= 2.7e34) | ((t>= 59496) & (t<59505))
gx339_mask = ~to_exclude
lr_filtered, lx_filtered, dlr_filtered, dlx_l_filtered, dlx_u_filtered ,  delta_filtered = lr[gx339_mask], lx[gx339_mask], dlr[gx339_mask], dlx_l[gx339_mask], dlx_u[gx339_mask],  delta[gx339_mask]
x_filtered, y_filtered, dx_filtered, dy_filtered, delta_filtered = x[gx339_mask], y[gx339_mask], dx[gx339_mask], dy[gx339_mask], delta[gx339_mask]


print(f"Number of GX 339-4 data points included: {sum(gx339_mask)}")

## Plot the selected data points

plt.errorbar(lx, lr, yerr=dlr, xerr=[dlx_l, dlx_u], fmt=".")
plt.errorbar(lx_filtered, lr_filtered, yerr=dlr_filtered, xerr=[dlx_l_filtered, dlx_u_filtered], fmt=".", color="red")
plt.xscale("log")
plt.yscale("log")
#plt.xlim(min_Lx, max_Lx)
#plt.ylim(min_Lr, max_Lr_2)
plt.show()
# Out:
# Number of GX 339-4 data points included: 70

# %%
## Look to see how distance affects GX339

plt.errorbar(x, y, yerr=dy, xerr=dx, fmt=".")
plt.errorbar(x_filtered, y_filtered, yerr=dy_filtered, xerr=dx_filtered, fmt=".", color="red")
plt.errorbar(x_filtered + 2*np.log10(8 / 10), y_filtered + 2*np.log10(8 / 10), yerr=dy_filtered, xerr=dx_filtered, fmt=".", color="green")
plt.errorbar(x_filtered + 2*np.log10(12/ 10), y_filtered+ 2*np.log10(12 / 10), yerr=dy_filtered, xerr=dx_filtered, fmt=".", color="pink")
#plt.xlim(min_Lx, max_Lx)
#plt.ylim(min_Lr, max_Lr_2)
plt.show()

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, K=3, seed=42, parallel=False, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,verbose= True, gx_339_filtered=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# Number of GX 339-4 data points included: 70
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06910481 1.06650205 0.99344295 1.022725   0.99663089 0.99306833]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02627517 1.02630294 0.9957681  1.00880968 0.99732339 0.9963839 ]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00500179 1.005988   0.99699426 1.00185649 0.99801162 0.99765684]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99890418 0.99990634 0.99893877 1.00018025 1.0000057  0.99929138]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00148345 1.00407218 0.99973368 1.00173151 0.99988561 1.00097807]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00054988 1.00134279 0.99960135 1.00124294 1.00015137 0.99852567]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986593 1.00130015 1.00136975 1.00060702 1.00012646 0.99966622]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038879 1.00188038 1.00342871 1.00083707 1.00017714 1.00096852]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000981   1.00319331 1.00392554 1.00107204 1.00011459 1.00045334]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00098076 1.00358081 1.00171316 1.00134059 1.00012425 0.99951921]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00165588 1.00534929 1.00202226 1.00175112 1.00025363 0.99941067]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00166964 1.00506169 1.0015994  1.00156115 1.00020355 0.99937056]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00198077 1.00507096 1.00197811 1.00172422 1.00020093 0.99963066]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00362409 1.00395075 1.00283909 1.00286532 1.00024397 0.99980245]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00262598 1.00349021 1.00260215 1.00233086 0.99968569 1.00001419]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00229391 1.00376508 1.0029812  1.00131717 0.99970805 1.00034921]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00189532 1.00238208 1.00160593 1.00113388 0.99972201 1.00000397]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00183609 1.00190507 1.0014298  1.00086701 0.99973293 0.9998433 ]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00391844 1.00334142 1.00168234 1.00060362 0.999736   0.99993347]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0044843  1.00357957 1.00147413 1.00026586 0.99975243 1.00007199]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0058499  1.00413397 1.00118367 1.00049582 0.99974301 1.00010924]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00645668 1.0043305  1.00087377 1.00050573 0.99971346 1.0000586 ]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00533572 1.00347376 1.00057339 1.00053446 0.99971897 1.00021507]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00597151 1.00401721 1.00100789 1.0007678  1.00011956 1.00041725]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00535312 1.00380155 1.00092887 1.00071375 1.00012062 1.00049384]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.005081   1.00311016 1.00067972 1.00062927 0.99986566 1.00091942]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00513965 1.00298299 1.00041672 1.00055961 0.99987249 1.00068293]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00588353 1.00389395 1.0002097  1.0004076  0.9998763  1.00037659]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00536256 1.0037567  0.99994045 1.00049579 0.99988027 1.0000739 ]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00552183 1.0036762  0.99981633 1.00053197 0.9998834  0.9998497 ]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00574796 1.00386535 0.99988623 1.00039001 0.99988718 0.99983263]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00527071 1.00359311 1.00009869 1.00051306 0.99989129 0.99995277]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00458874 1.00317361 1.0001755  1.00030492 0.99989458 1.00017649]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00573624 1.00361251 1.00015944 1.00027731 0.9998948  1.00014533]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00497794 1.00312484 1.00001846 1.00017573 0.99989712 1.00008982]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00478971 1.00286835 0.99992268 1.00016585 0.99990299 1.00014233]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00484891 1.00290227 0.99988628 1.00009763 0.99990537 1.00010434]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00406184 1.00212546 0.99981961 1.00007156 0.99988189 0.99996503]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00329263 1.00184516 0.99989489 1.00012469 0.99988453 1.00006667]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00307855 1.00163659 0.99987065 1.00011326 0.99988923 0.99993492]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00342449 1.00176976 0.99989987 1.0000965  0.99989276 0.99992954]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00300071 1.00127421 0.99990541 1.00003354 0.99989413 0.99993499]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0030281  1.00135875 0.99981374 0.9999919  0.99989709 0.99990116]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00281868 1.00136179 0.99985713 1.00006043 0.99989984 0.9999003 ]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00331952 1.00147085 0.9998751  1.00010798 0.99990266 0.99981234]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00288116 1.00126902 0.99985998 1.00016798 0.99990528 0.99982444]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00273586 1.00125867 0.99985505 1.0001804  0.99990754 0.99983882]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00278885 1.00121453 0.99983641 1.00011633 0.99990937 0.99989614]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00220259 1.00083676 0.99986302 1.00025154 0.99991179 0.99986076]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00199452 1.00068351 0.99990934 1.00027813 0.99991268 0.99983863]
# Length of chain: 10000

# %%
linmix_results(N_runs =1, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,  gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# Number of GX 339-4 data points included: 70
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.377  -0.015  +0.014
# Beta  = 0.588  -0.012  +0.012
# Sigma = 0.059  -0.008  +0.008
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.377  -0.015  +0.014
# Beta  = 0.588  -0.012  +0.012
# Sigma = 0.059  -0.008  +0.009
# The 90% lower limit on beta from all values
# Beta > 0.572
# The 90% upper limit on beta from all values
# Beta < 0.603
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.377  -0.015  +0.014
# Beta =  0.588  -0.012  +0.012
# Sigma =  0.059  -0.008  +0.009
# The 90% lower limit on beta from run results
# Beta >  0.57
# The 90% upper limit on beta from run results
# Beta <  0.6

# %%
# Compare with ODR result
# Should be quite similar since the intrinsic scatter is small
# Recall though that this only deals with detections

import scipy.odr as odr

mask_filtered_det = delta_filtered.astype(bool)
x_filtered_det = x_filtered[mask_filtered_det]
y_filtered_det = y_filtered[mask_filtered_det]
dx_filtered_det = dx_filtered[mask_filtered_det]
dy_filtered_det = dy_filtered[mask_filtered_det]

# Define the linear model for ODR
def linear_func(beta, x):
    return beta[0] * x + beta[1]

# Create a model object
model = odr.Model(linear_func)

# Create a data object with errors
data = odr.RealData(x_filtered_det, y_filtered_det, sx=dx_filtered_det, sy= dy_filtered_det)

# Set up the ODR with an initial guess
odr_instance = odr.ODR(data, model, beta0=[1.0, 0.0])

# Run the regression
output = odr_instance.run()

# Get the fitted parameters
slope, intercept = output.beta
slope_err, intercept_err = output.sd_beta
print(f"Fitted parameters:")
print(f"  Slope = {slope:.3f} ± {slope_err:.3f}")
print(f"  Intercept = {intercept:.3f} ± {intercept_err:.3f}")
# Out:
# Fitted parameters:
#   Slope = 0.588 ± 0.014
#   Intercept = 0.379 ± 0.018
# C:\Users\justi\AppData\Local\Temp\ipykernel_3136\1461211049.py:5: DeprecationWarning: `scipy.odr` is deprecated as of version 1.17.0 and will be removed in SciPy 1.19.0. Please use `https://pypi.org/project/odrpack/` instead.
#   import scipy.odr as odr

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, K=3, seed=42, parallel=True, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,verbose= True, gx_339_filtered=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# 70 data points remain after filtering for GX 339-4 region of interest
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_100
# 100%|██████████| 100/100 [03:48<00:00,  2.29s/it]

# %%
linmix_results(N_runs =100, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,  gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# Number of GX 339-4 data points included: 70
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.370  -0.051  +0.050
# Beta  = 0.588  -0.012  +0.012
# Sigma = 0.059  -0.008  +0.008
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.371  -0.052  +0.049
# Beta  = 0.588  -0.012  +0.012
# Sigma = 0.059  -0.008  +0.009
# The 90% lower limit on beta from all values
# Beta > 0.572
# The 90% upper limit on beta from all values
# Beta < 0.604
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.370  -0.015  +0.014
# Beta =  0.588  -0.012  +0.012
# Sigma =  0.059  -0.008  +0.009
# The 90% lower limit on beta from run results
# Beta >  0.57
# The 90% upper limit on beta from run results
# Beta <  0.6

# %%
# Upper bound for the slope from GX 339-4 
0.588 + 0.012
# Out:
# 0.6
