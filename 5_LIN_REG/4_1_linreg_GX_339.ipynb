# %% [markdown]
# # GX 339-4

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["GX 339-4"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01608291 1.04869228 1.0364667  1.00762626 0.99688566 1.0008475 ]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.02379821 1.04561961 1.03955649 1.00550755 1.0032165  1.01101019]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01911227 1.03420701 1.03693748 1.00120445 1.00228107 1.01409516]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00985069 1.01929975 1.01466235 1.00108913 1.00287649 1.00393287]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00077302 1.00556227 1.00777585 1.00054435 1.00310098 1.00562285]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99967555 1.00167367 1.00282264 1.00017722 1.00230984 1.00296363]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99912371 1.00027632 1.00403798 0.99947904 1.00201437 1.0033125 ]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99954498 1.00138283 1.00208493 0.99968171 1.00196945 1.0017096 ]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997011  1.00190186 1.00039925 0.99964245 1.00102388 1.00055631]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983009 1.00019499 1.00055346 0.99938834 1.00071325 1.00039925]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00002739 1.00090237 1.00085268 0.99970841 1.00026075 0.99999286]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010963 1.00037079 1.00057157 1.00004115 1.00028719 1.00041349]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998654  0.99967487 1.00122129 0.99979078 1.00032105 1.00089241]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00053828 1.00053631 1.00085249 0.99966292 1.00057946 1.00047692]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999692 0.9997913  1.000778   0.99968275 0.99997541 1.00060977]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00076457 1.00036358 1.00078398 0.99973593 0.99971843 1.00019746]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039928 1.00082481 1.00145484 0.99964135 0.9998089  1.00037746]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027228 1.00090757 1.00181281 0.99971163 0.99968713 1.00073907]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00033331 1.00083458 1.00269954 0.99974669 0.99980347 1.00142334]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00073212 1.000902   1.00260646 0.99986462 0.9997836  1.0013456 ]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00108379 1.0015607  1.00267393 0.99976939 0.99986869 1.00135079]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00105134 1.00152132 1.00200697 0.99972385 0.99991812 1.00100548]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00062469 1.00140774 1.00216113 0.9997653  0.99997011 1.00102305]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069393 1.00200924 1.00191615 0.99970208 1.00020533 1.00058586]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00084191 1.00211715 1.00184905 0.99961764 1.00018599 1.00053497]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00109837 1.00240577 1.00219324 0.99963662 1.00038651 1.00065881]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00102745 1.00204278 1.00223677 0.99967635 1.00053877 1.00077371]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00057284 1.00134895 1.0015633  0.99968602 1.00079699 1.00047021]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058879 1.00096309 1.00127589 0.99966722 1.0010273  1.00052022]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0004619  1.00081824 1.00140411 0.9997031  1.00127736 1.00052207]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069028 1.00116051 1.0015304  0.99973436 1.00126422 1.00069997]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00060726 1.00079396 1.00138249 0.99974588 1.00136765 1.00078164]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00081008 1.00102133 1.00129664 0.9997797  1.00134815 1.00065584]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0011155  1.00117893 1.00119563 0.99978111 1.00139514 1.00066854]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00100265 1.00112033 1.00117123 0.99975301 1.00121159 1.00055744]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00111471 1.00113827 1.00122662 0.99976947 1.00129465 1.00060741]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0008931  1.00090902 1.00127979 0.99978874 1.00117958 1.00068864]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00152684 1.00165539 1.00146397 0.99977796 1.00123331 1.00067065]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00154841 1.00177685 1.00120174 0.99977157 1.00104255 1.00042873]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00153901 1.00189088 1.00127166 0.99977128 1.00089418 1.00036628]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00164951 1.00189316 1.00105663 0.99978632 1.00094491 1.00033083]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00171517 1.00211904 1.00128412 0.99980342 1.00115506 1.00049962]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00178744 1.0021672  1.00134404 0.99978618 1.00113984 1.00058446]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00149505 1.00187028 1.0012894  0.99980715 1.00116789 1.00065881]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00127819 1.00174427 1.00126079 0.999828   1.00098708 1.00064632]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0014083  1.00203165 1.00125713 0.99983693 1.0009568  1.00061103]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0015337  1.00217425 1.00127817 0.99981074 1.00093299 1.000561  ]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00171905 1.00211768 1.00152635 0.99980603 1.00091285 1.0007555 ]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00163643 1.00194217 1.00146283 0.99982982 1.00090938 1.00074377]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00195509 1.00202894 1.001662   0.99984122 1.00082075 1.0007939 ]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.453  -0.028  +0.028
# Beta  = 0.611  -0.025  +0.024
# Sigma = 0.263  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.454  -0.029  +0.027
# Beta  = 0.611  -0.024  +0.025
# Sigma = 0.262  -0.022  +0.025
# The 90% lower limit on beta from all values
# Beta > 0.580
# The 90% upper limit on beta from all values
# Beta < 0.643
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.454  -0.029  +0.027
# Beta =  0.611  -0.024  +0.025
# Sigma =  0.262  -0.022  +0.025
# The 90% lower limit on beta from run results
# Beta >  0.58
# The 90% upper limit on beta from run results
# Beta <  0.64

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, seed=5, interp=True, type_source=None, names = ["GX 339-4"], parallel=True, verbose =True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_100
# 100%|██████████| 100/100 [04:51<00:00,  2.92s/it]

# %%
linmix_results(N_runs=100, interp=True, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.450  -0.053  +0.053
# Beta  = 0.611  -0.025  +0.024
# Sigma = 0.263  -0.023  +0.023
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.451  -0.054  +0.052
# Beta  = 0.611  -0.024  +0.025
# Sigma = 0.261  -0.022  +0.025
# The 90% lower limit on beta from all values
# Beta > 0.580
# The 90% upper limit on beta from all values
# Beta < 0.644
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.450  -0.028  +0.027
# Beta =  0.611  -0.024  +0.025
# Sigma =  0.261  -0.022  +0.025
# The 90% lower limit on beta from run results
# Beta >  0.58
# The 90% upper limit on beta from run results
# Beta <  0.64

# %% [markdown]
# ---

# %% [markdown]
# # Paired Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=False, type_source=None, names = ["GX 339-4"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_paired_['GX 339-4']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.06365932 1.07831425 1.06840872 1.02330751 1.00302748 1.03548232]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00325442 1.01897661 1.01516494 1.0087423  1.00123301 1.01600813]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00627299 1.00862895 1.01063462 1.00300188 1.00203592 1.01808672]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01304668 1.02198294 1.02418781 1.00103123 1.00148494 1.01493953]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00980159 1.01114575 1.01745069 0.99972967 1.00116557 1.01394038]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00583534 1.0113596  1.01266069 0.99916458 1.00092292 1.01095496]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00517355 1.01012681 1.0089438  0.99879979 0.9999852  1.00507609]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00604953 1.01446246 1.0110832  0.99882148 0.9999889  1.00366237]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00319141 1.01016043 1.00516077 0.99965926 0.99999092 1.00221764]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991656 1.00409566 1.00103403 0.99940949 0.99999308 1.00087224]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997675 1.0022125  0.99974009 0.99947849 0.99999371 1.00036427]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039399 1.00289046 0.99997602 0.99958171 0.99999473 1.00044769]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00063511 1.00282021 1.00079004 0.99960977 0.99999174 1.00025331]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0009717  1.00300662 1.00014469 0.99950451 0.99999176 0.99996474]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069123 1.00211141 1.0006246  0.99969337 0.99999139 1.00000699]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0003957  1.00246786 1.00109107 0.99980393 0.99999126 1.00007519]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021979 1.00284584 1.0007204  0.99994844 0.9999922  1.00012924]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035734 1.0014375  1.00099242 0.99993704 0.9999045  1.00067235]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016916 1.00101886 1.00055959 0.99976754 0.99990817 1.00059714]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986695 1.00097124 1.00096433 0.99966166 0.99991296 1.00098107]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00033329 1.00187944 1.00222559 0.99965162 0.99991671 1.00147808]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00043708 1.00171178 1.00126464 0.99971725 0.99992045 1.0009189 ]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034407 1.00129601 1.00151913 0.99976324 0.99992243 1.00103772]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005767 1.00081185 1.00116021 0.99983428 0.99992579 1.00106153]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007972 1.00038495 1.00160042 0.99980855 0.99992853 1.00103844]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998611 1.00025991 1.00138553 0.99988072 0.99993137 1.00095003]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003796 1.00030277 1.00154413 0.99989972 0.99993375 1.00104045]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990637 1.00018606 1.00086239 0.99987649 0.9999363  1.00072031]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973616 0.99995536 1.00046586 0.99986743 0.99993829 1.00051752]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975125 0.99974025 1.00065828 0.99991408 0.99994028 1.00061223]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998425  1.00000731 1.00062539 0.99987619 0.99994228 1.00056083]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996912 1.00024029 1.00065695 0.99984527 0.99994389 1.0005406 ]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992648 1.00051405 1.00051475 0.99990638 0.99994565 1.00048195]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998228  1.0003768  1.00045339 0.99992633 0.99994717 1.00040809]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998695  1.00038539 1.00062767 0.99987462 0.9999484  1.00047414]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988282 1.00042896 1.00043032 0.99987725 0.99995003 1.00042711]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995663 1.00016105 1.00043139 0.99991587 0.99995126 1.00032013]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999776  1.00016417 1.00041636 0.9999449  0.99995243 1.00028511]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991809 1.00022237 1.00030883 0.99985774 0.99995356 1.00031103]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982894 1.00035506 1.00014834 0.99988224 0.99995484 1.00019192]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980147 1.00041195 1.00014602 0.99989353 0.99995603 1.00020171]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985063 1.00024748 1.00024717 0.99991817 0.999957   1.00030152]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989299 1.00027446 1.00040485 0.99995086 0.99995797 1.00036646]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000277 1.0002757  1.00064541 0.99991091 0.99995877 1.00055873]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00032183 1.0002721  1.00098573 0.99993806 0.99995932 1.00056764]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046524 1.00062286 1.00129118 0.99995786 0.99995992 1.0005307 ]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048004 1.00052735 1.00108737 0.99991534 0.99996073 1.00045387]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045799 1.0006959  1.00119334 0.99995068 0.99996164 1.00053762]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00043903 1.00048219 1.00106307 0.99993957 0.99996188 1.00048417]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037274 1.00056668 1.0010292  0.99989269 0.99996269 1.00053741]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=False, type_source=None, names=["GX 339-4"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_['GX 339-4']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.471  -0.035  +0.035
# Beta  = 0.606  -0.031  +0.030
# Sigma = 0.275  -0.030  +0.030
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.471  -0.036  +0.034
# Beta  = 0.606  -0.030  +0.031
# Sigma = 0.272  -0.027  +0.032
# The 90% lower limit on beta from all values
# Beta > 0.567
# The 90% upper limit on beta from all values
# Beta < 0.646
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.471  -0.036  +0.034
# Beta =  0.606  -0.030  +0.031
# Sigma =  0.272  -0.027  +0.032
# The 90% lower limit on beta from run results
# Beta >  0.57
# The 90% upper limit on beta from run results
# Beta <  0.65

# %% [markdown]
# ---

# %% [markdown]
# # Excluding points with ejecta contamination

# %%
## Check data filtering

lr0, lx0, lr, dlr, delta_radio, lx, dlx_l, dlx_u, delta_xrays, source_names, unique_names, unique_D, unique_D_prob, t = get_data_arrays(names = ["GX 339-4"], interp=True, rerun = False, save=False, incl_Fr_uplims=True, type_source="BH")
delta = delta_radio.astype(int) # Convert boolean to int (1 for detection, 0 for upper limit)


# x:
lx_scaled = lx/lx0
log_lx_scaled = np.log10(lx_scaled) # x
log_dlx_l_scaled = np.log10(lx / (lx - dlx_l)) # = log(lx/lx0) - log( (lx - dlx_l)/ lx0 ) 
log_dlx_u_scaled = np.log10( ( lx + dlx_u) / lx ) # = log( (lx + dlx_u)/ lx0 ) - log(lx/lx0)
log_dlx_scaled = np.maximum(log_dlx_l_scaled , log_dlx_u_scaled )

# y:
lr_scaled = lr/lr0
log_lr_scaled = np.log10(lr_scaled) # y
log_dlr_l_scaled = np.log10(lr / (lr - dlr))
log_dlr_u_scaled = np.log10( ( lr + dlr) / lr )
log_dlr_scaled = np.maximum(log_dlr_l_scaled , log_dlr_u_scaled )

x = log_lx_scaled
y = log_lr_scaled
dx = log_dlx_scaled
dy = log_dlr_scaled


## Filter for region of interest

t0 = 58964
t1 = 59083
gx339_mask = (lx > 2.7e34) & ( (t<t0) | (t>t1) )
lr_filtered, lx_filtered, dlr_filtered, dlx_l_filtered, dlx_u_filtered ,  delta_filtered = lr[gx339_mask], lx[gx339_mask], dlr[gx339_mask], dlx_l[gx339_mask], dlx_u[gx339_mask],  delta[gx339_mask]
x_filtered, y_filtered, dx_filtered, dy_filtered, delta_filtered = x[gx339_mask], y[gx339_mask], dx[gx339_mask], dy[gx339_mask], delta[gx339_mask]


## Plot the selected data points

plt.errorbar(lx, lr, yerr=dlr, xerr=[dlx_l, dlx_u], fmt=".")
plt.errorbar(lx_filtered, lr_filtered, yerr=dlr_filtered, xerr=[dlx_l_filtered, dlx_u_filtered], fmt=".", color="red")
plt.xscale("log")
plt.yscale("log")
#plt.xlim(min_Lx, max_Lx)
#plt.ylim(min_Lr, max_Lr_2)
plt.show()
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1

# %%
## Look to see how distance affects GX339

plt.errorbar(x, y, yerr=dy, xerr=dx, fmt=".")
plt.errorbar(x_filtered, y_filtered, yerr=dy_filtered, xerr=dx_filtered, fmt=".", color="red")
plt.errorbar(x_filtered + 2*np.log10(8 / 10), y_filtered + 2*np.log10(8 / 10), yerr=dy_filtered, xerr=dx_filtered, fmt=".", color="green")
plt.errorbar(x_filtered + 2*np.log10(12/ 10), y_filtered+ 2*np.log10(12 / 10), yerr=dy_filtered, xerr=dx_filtered, fmt=".", color="pink")
#plt.xlim(min_Lx, max_Lx)
#plt.ylim(min_Lr, max_Lr_2)
plt.show()

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, K=3, seed=42, parallel=False, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,verbose= True, gx_339_filtered=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_1
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0249078  1.01506991 1.00157471 1.00422145 0.99298613 0.99252054]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99600457 0.99694051 1.01126127 0.99965229 1.00157029 1.01227047]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00266843 1.00365451 1.01625599 1.00216273 0.99989888 1.00618938]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01364375 1.01058303 1.01679656 1.00155484 0.99993252 1.00544909]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00259171 1.00629847 1.01191053 1.00295167 0.99986384 1.00339794]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00363203 1.00493283 1.01270659 1.0009809  0.99989227 1.00366195]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00089047 1.00129506 1.01088046 1.00019151 0.99994762 1.00291028]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00155391 1.00218228 1.00926735 1.00270752 0.99987098 1.0027573 ]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139136 1.00257154 1.00737638 1.00281598 1.00037485 1.00167809]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00214758 1.00295005 1.0058637  1.00220281 1.00036573 1.0011644 ]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.001843   1.00257988 1.00580315 1.00204996 1.00035086 1.00129824]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0019946  1.00266871 1.00606215 1.00146725 1.00031593 1.00198265]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00061677 1.00112339 1.00693775 1.0010185  1.00029556 1.00248903]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00133771 1.00155552 1.00594789 1.00078127 1.00029152 1.0026838 ]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00053979 1.00055292 1.00443236 1.00031298 1.00031678 1.00131622]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981177 1.00019611 1.00371703 1.00049213 1.00034574 1.00150742]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035099 1.00080386 1.00433088 1.00030074 1.00036649 1.0022262 ]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00033499 1.0007713  1.00312362 1.00075644 1.0001885  1.00159125]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979718 1.00027106 1.00282553 1.00057934 1.00009073 1.001399  ]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992778 1.00054536 1.00279087 1.00076199 1.00005375 1.00144007]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039879 1.00101697 1.00228713 1.00107451 1.00012159 1.00149682]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013355 1.00054676 1.00250927 1.00152597 1.00008394 1.0016357 ]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0001224  1.00040733 1.00221907 1.0013384  1.00008616 1.00123651]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00069578 1.00068008 1.00235043 1.00148599 1.00005073 1.00122708]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0006123  1.0007394  1.00187493 1.00122099 1.00001696 1.00086643]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00108015 1.001312   1.00123854 1.00085819 0.99997753 1.00057583]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00071664 1.00111157 1.00069639 1.00058286 0.99996435 1.00045093]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037572 1.00065264 1.00101027 1.00052954 0.99995379 1.00080245]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058636 1.00080072 1.00095986 1.00053272 0.99994269 1.00049371]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00086584 1.00104561 1.00134847 1.00090933 0.99996642 1.00077386]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00051837 1.0005423  1.00158161 1.00084646 0.99995617 1.00077734]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00064547 1.00072271 1.0019623  1.00094861 0.99983309 1.00077464]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00073494 1.00092716 1.00194715 1.00091874 0.99985    1.00065927]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035522 1.00073688 1.00168072 1.0009215  0.9998541  1.00056541]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00044952 1.00084908 1.00131934 1.0007727  0.99984613 1.00048881]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021955 1.0006415  1.00122416 1.00083676 0.99984409 1.00057095]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00008983 1.0003721  1.00097016 1.00068472 0.99984802 1.00044181]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999906 1.00026956 1.0004508  1.0007271  0.99985153 1.00016412]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99994733 1.00018186 1.0002602  1.00050653 0.9999413  0.99998072]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982919 1.00007057 1.00034892 1.00034994 1.00009148 0.99993181]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980543 1.00001807 1.00043642 1.00042789 1.00009014 0.99999521]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981612 1.00010057 1.00034186 1.00029364 1.00009818 0.9999601 ]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980005 1.00004903 1.00040629 1.00028329 1.00009088 1.00003024]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998832  1.00014806 1.00031546 1.00014752 1.00008795 1.00001231]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995387 1.00028203 1.00030322 1.00010456 1.00008242 0.9999916 ]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000534 1.00024307 1.00022413 1.00007502 1.00008063 0.99997902]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998648 1.0002183  1.00015068 1.00002641 1.00007747 0.99994081]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006045 1.00027299 1.00013381 1.00000084 1.00007811 0.99990184]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0000004  1.0001262  1.00015061 0.99999243 1.00021933 0.99998848]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012102 1.00028507 1.0001832  0.99998886 1.00021461 0.999975  ]
# Length of chain: 10000

# %%
linmix_results(N_runs =1, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,  gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.394  -0.017  +0.017
# Beta  = 0.590  -0.015  +0.015
# Sigma = 0.080  -0.009  +0.009
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.394  -0.017  +0.017
# Beta  = 0.590  -0.015  +0.015
# Sigma = 0.079  -0.009  +0.010
# The 90% lower limit on beta from all values
# Beta > 0.571
# The 90% upper limit on beta from all values
# Beta < 0.609
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.394  -0.017  +0.017
# Beta =  0.590  -0.015  +0.015
# Sigma =  0.079  -0.009  +0.010
# The 90% lower limit on beta from run results
# Beta >  0.57
# The 90% upper limit on beta from run results
# Beta <  0.61

# %%
# Compare with ODR result
# Should be quite similar since the intrinsic scatter is small
# Recall though that this only deals with detections

import scipy.odr as odr

mask_filtered_det = delta_filtered.astype(bool)
x_filtered_det = x_filtered[mask_filtered_det]
y_filtered_det = y_filtered[mask_filtered_det]
dx_filtered_det = dx_filtered[mask_filtered_det]
dy_filtered_det = dy_filtered[mask_filtered_det]

# Define the linear model for ODR
def linear_func(beta, x):
    return beta[0] * x + beta[1]

# Create a model object
model = odr.Model(linear_func)

# Create a data object with errors
data = odr.RealData(x_filtered_det, y_filtered_det, sx=dx_filtered_det, sy= dy_filtered_det)

# Set up the ODR with an initial guess
odr_instance = odr.ODR(data, model, beta0=[1.0, 0.0])

# Run the regression
output = odr_instance.run()

# Get the fitted parameters
slope, intercept = output.beta
slope_err, intercept_err = output.sd_beta
print(f"Fitted parameters:")
print(f"  Slope = {slope:.3f} ± {slope_err:.3f}")
print(f"  Intercept = {intercept:.3f} ± {intercept_err:.3f}")
# Out:
# Fitted parameters:
#   Slope = 0.597 ± 0.019
#   Intercept = 0.390 ± 0.022
# C:\Users\justi\AppData\Local\Temp\ipykernel_19928\1461211049.py:5: DeprecationWarning: `scipy.odr` is deprecated as of version 1.17.0 and will be removed in SciPy 1.19.0. Please use `https://pypi.org/project/odrpack/` instead.
#   import scipy.odr as odr

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, K=3, seed=42, parallel=True, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,verbose= True, gx_339_filtered=True)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_100
# 100%|██████████| 100/100 [03:19<00:00,  2.00s/it]

# %%
linmix_results(N_runs =100, names = ["GX 339-4"], interp=True, type_source=None, include_Fr_uplims=True,  gx_339_filtered=True)
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['GX 339-4']_GX339_filtered_Nruns_100
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['GX 339-4']
# Sources included after filtering:  ['GX 339-4']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.388  -0.051  +0.050
# Beta  = 0.590  -0.015  +0.015
# Sigma = 0.080  -0.009  +0.009
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.389  -0.052  +0.050
# Beta  = 0.589  -0.015  +0.015
# Sigma = 0.080  -0.009  +0.010
# The 90% lower limit on beta from all values
# Beta > 0.570
# The 90% upper limit on beta from all values
# Beta < 0.609
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.389  -0.017  +0.017
# Beta =  0.589  -0.015  +0.015
# Sigma =  0.080  -0.009  +0.010
# The 90% lower limit on beta from run results
# Beta >  0.57
# The 90% upper limit on beta from run results
# Beta <  0.61

# %%
# Upper bound for the slope from GX 339-4 
0.589 + 0.015
# Out:
# 0.604
