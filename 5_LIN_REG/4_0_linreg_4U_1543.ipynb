# %% [markdown]
# # 4U 1543-47

# %%
import sys
import pandas as pd
import numpy as np
import os
sys.path.append(os.path.abspath("../0_UTILITY_FUNCTIONS/"))
from linreg import *

# %% [markdown]
# ---

# %% [markdown]
# # Using Interpolated Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=True, type_source=None, names = ["4U 1543-47"], parallel=False)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['4U 1543-47']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_1
# Running MCMC iteration 0 with min_iter=5000 and max_iter=7000
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0025133  1.00481933 1.03586797 1.03889224 0.99573714 0.99148146]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00841706 1.00317895 1.00687988 1.00770601 1.00079693 1.00022174]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00176863 0.99931402 1.004779   1.00643606 1.00011573 0.99877733]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995056 0.99899456 1.00075308 1.00115239 1.00026694 0.99934957]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99943754 0.99878056 1.00152514 1.00286149 1.00062363 0.99912941]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99882773 0.99903741 1.00087034 1.0012972  0.99932947 0.9993825 ]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99876745 0.99923333 1.00086558 1.00204491 0.99933419 0.99945911]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99943721 1.00016146 0.99943244 1.00257486 0.99963871 0.99945581]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99929278 1.00068302 1.00049815 1.00163687 0.99992298 0.99938773]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9992591  0.99975498 1.00054486 1.00172174 0.99993931 0.99991734]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99926996 0.99956005 1.00078122 1.00152614 0.99993567 0.99927723]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99953059 0.99957121 1.00098798 1.00125858 0.99993868 0.99945744]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99945957 0.99984118 1.00127226 1.00123294 0.9999442  0.99951879]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99958229 0.99980909 1.00159418 1.00090739 0.99994871 0.99946629]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99958813 0.99964364 1.00204386 1.00107293 0.99978944 0.99961279]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99952699 0.99962549 1.00087417 1.00096248 0.99978406 1.0000564 ]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99948034 0.99952419 1.00107369 1.00089499 0.99979279 1.00026106]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99951435 0.99954589 1.0010683  1.00041117 0.99980438 1.00032564]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99966151 0.99968508 1.00099694 1.00039151 0.99981481 1.00007501]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99964131 0.99959616 1.00080343 1.00021767 0.99981558 0.99996429]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99962365 0.99961122 1.0006699  0.99965523 0.99975753 1.00011444]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99959284 0.99964138 1.00056307 0.9997787  0.99976884 1.00035171]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99960843 0.99961379 1.00031029 0.99984691 0.99977855 1.00027364]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99959775 0.99961683 1.0004745  0.99970045 0.99980336 1.0003711 ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99963077 0.99967097 1.00035265 0.99977209 0.99981086 1.00015255]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99965213 0.99970179 1.00032528 0.99966351 0.99981171 0.99997931]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99965012 0.99966423 1.00038339 0.99964905 0.99994929 0.99992129]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99967937 0.99967005 1.00048666 0.99970828 0.99996432 1.00002837]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99968078 0.99967271 1.00051808 0.99970006 0.99985728 0.99992872]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99969244 0.99971904 1.00048697 0.9997379  0.99986206 0.99994543]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972778 0.99973916 1.00043329 0.99971447 0.99986612 0.99983502]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975689 0.99974448 1.00050247 0.99974394 0.9999597  0.99977335]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981473 0.99975924 1.00051012 0.99979256 0.99996077 0.9998443 ]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998041  0.99977749 1.00066179 0.99985693 0.99996517 0.99993315]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981195 0.99980143 1.00052018 0.99995699 0.99996641 0.99983767]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980925 0.99982401 1.00044083 1.00006354 0.9999677  0.9998466 ]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979417 0.99980111 1.00028217 1.00005564 0.99996142 0.99999018]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979146 0.99981685 1.00011544 1.00008579 0.99996252 0.99995622]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978827 0.99982949 0.9999787  0.99997081 0.99996225 0.99994349]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997932  0.99984553 0.99997683 0.99998448 0.9999634  0.99991925]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981167 0.99987484 0.99995279 1.0000474  0.99996447 0.99992976]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983408 0.99987095 0.9999502  0.9999318  0.99996526 0.99991086]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984689 0.99991541 0.99993451 0.99991962 0.99996998 0.99986903]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984127 0.99990616 0.99989527 0.99997771 0.99996849 0.99987476]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983221 0.99991756 0.99996819 0.99996153 1.00002027 0.99980834]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981131 0.99983705 0.99992787 0.9999083  1.00018868 0.99980592]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982944 0.99981542 1.00003845 0.99991866 1.00018399 0.99979332]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986019 0.9998219  1.00006677 0.99987762 1.00018005 0.99981638]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984    0.99980595 1.00005212 0.9998807  1.00017502 0.99982409]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982438 0.99980246 1.00005877 0.99989575 1.00017137 0.9998354 ]
# Length of chain: 10000

# %%
linmix_results(N_runs=1, interp=True, type_source=None, names=["4U 1543-47"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_1
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['4U 1543-47']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.836  -0.088  +0.090
# Beta  = 0.903  -0.130  +0.131
# Sigma = 0.256  -0.065  +0.063
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.837  -0.089  +0.089
# Beta  = 0.903  -0.130  +0.130
# Sigma = 0.242  -0.052  +0.077
# The 90% lower limit on beta from all values
# Beta > 0.736
# The 90% upper limit on beta from all values
# Beta < 1.074
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.837  -0.089  +0.089
# Beta =  0.903  -0.130  +0.130
# Sigma =  0.242  -0.052  +0.077
# The 90% lower limit on beta from run results
# Beta >  0.74
# The 90% upper limit on beta from run results
# Beta <  1.07

# %% [markdown]
# ### 100 Runs

# %%
run_linmix(N_runs=100, seed=5, interp=True, type_source=None, names = ["4U 1543-47"], parallel=True, verbose=True)
# Out:
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['4U 1543-47']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_100
# 100%|██████████| 100/100 [01:55<00:00,  1.15s/it]

# %%
linmix_results(N_runs=100, interp=True, type_source=None, names=["4U 1543-47"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_interp_['4U 1543-47']_Nruns_100
# Include X-ray upper limits?:  False
# Include radio upper limits?:  True
# Filter GX 339-4 branch?:  False
# lr0:  4.54e+28
# lx0:  7.51e+35
#
# Source names:  ['4U 1543-47']
# Getting LrLx data using interpolation with method  akima
# Using saved pairing/interpolation results for source, with file name:  ../DATA/INTERPOLATED/4U 1543-47_Lr_Lx_interp_akima.csv
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# (1000000,) (1000000,) (1000000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.823  -0.102  +0.109
# Beta  = 0.903  -0.127  +0.127
# Sigma = 0.254  -0.064  +0.062
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.838  -0.117  +0.094
# Beta  = 0.903  -0.126  +0.127
# Sigma = 0.241  -0.051  +0.075
# The 90% lower limit on beta from all values
# Beta > 0.738
# The 90% upper limit on beta from all values
# Beta < 1.070
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.823  -0.108  +0.108
# Beta =  0.903  -0.126  +0.127
# Sigma =  0.241  -0.051  +0.075
# The 90% lower limit on beta from run results
# Beta >  0.74
# The 90% upper limit on beta from run results
# Beta <  1.07

# %% [markdown]
# ---

# %% [markdown]
# # Using Paired Data

# %% [markdown]
# ### One Run

# %%
run_linmix(N_runs=1, seed=5, interp=False, type_source=None, names = ["4U 1543-47"], parallel=False)
# Out:
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['4U 1543-47']
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# DIRECTORY:  ./MCMC_parfiles_paired_['4U 1543-47']_Nruns_1
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00908108 0.99715954 1.02846178 1.05085217 0.99979629 1.00647322]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972746 0.99588245 1.01103399 1.00199004 0.99987655 1.01042307]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99692356 0.99941748 1.00316188 1.00910048 0.99955236 1.00119761]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99839052 0.99995292 1.00165724 0.99884104 0.99962545 1.00144107]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99922633 1.0022436  1.00329962 0.99909778 1.00004464 1.00002546]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99903639 1.00236431 1.00109333 1.00044303 1.00002893 0.99934635]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99950286 1.00311867 1.00091691 1.00581933 1.00001341 0.9994838 ]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99947195 1.00228077 1.00530672 1.00397424 1.00001281 1.00088397]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99957978 1.00050835 1.00270852 0.99903981 1.00002105 1.00044463]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99929243 1.00017729 1.00238909 0.99904398 1.00009705 1.00028948]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99920491 0.99987464 1.00145906 0.999456   1.00008698 0.99987905]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99937076 0.99988732 1.00202498 0.99981344 1.00007444 1.0001402 ]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99947173 1.00000092 1.00147024 0.99990122 1.00006722 0.9999538 ]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99948787 0.99948821 1.00176458 0.99986315 1.00006686 0.99985976]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99946929 0.99943599 1.00283413 0.99981667 1.00016137 0.99983665]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99954999 0.99949349 1.00296828 0.99971803 1.00012436 0.99978291]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99965025 0.99971947 1.00391834 1.00006333 1.00011718 0.99999105]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975207 0.99964632 1.00335078 0.99993958 1.00011077 1.00023151]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973496 0.99970329 1.00216807 1.00019891 1.00010412 0.999855  ]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971963 0.99971163 1.00186486 1.00052103 1.0000031  0.99985034]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99966522 0.99973288 1.00151267 0.99988806 1.00000295 0.99987897]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99963443 0.9996678  1.00083984 0.99970361 1.00000283 0.99986013]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99970392 0.99975169 1.00128167 0.99981727 1.00002169 1.00014855]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99967796 0.9997977  1.00083535 0.99969286 1.0000202  0.99997444]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99965737 0.99965875 1.00081751 0.99973037 1.00001939 0.99994577]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973292 0.99971651 1.00089739 0.99977684 1.00001873 0.99983154]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99970413 0.99973801 1.00140223 0.99978123 1.00001803 0.99971495]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99970184 0.9998019  1.00205348 0.99983621 1.00001737 0.99973324]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99969951 0.9998188  1.00208293 0.9999524  1.0000168  0.99981291]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971019 0.9998014  1.00184306 1.00003206 1.00001625 0.99991133]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973313 0.99973915 1.00173288 1.00010029 1.00001573 0.99989837]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974037 0.99975002 1.0015872  1.00016386 1.00001523 0.99990835]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974666 0.99974656 1.0011561  1.0000081  1.00001457 0.99992387]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997271  0.99977076 1.00132953 1.0001192  1.00001414 0.99985721]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973783 0.99978479 1.00119354 1.0000946  1.00001374 0.99988916]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974483 0.99980493 1.00104875 0.99995041 1.00001336 0.99981703]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974624 0.99984071 1.00062697 0.99993517 1.00001299 0.99984559]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975078 0.99982193 1.00043289 1.00005328 1.00001171 0.99987935]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975819 0.99984972 1.0003889  1.00015983 1.00001141 0.99988354]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976127 0.99984881 1.00024622 1.00016229 1.00001112 0.99989524]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976647 0.999831   1.00076202 1.00027164 1.00001086 0.99995039]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99977199 0.99982734 1.00093423 1.00028468 1.00001056 0.99999017]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99977623 0.99981942 1.00102795 1.00031584 1.00001031 1.00006161]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978033 0.99982586 1.00103721 1.00128468 1.00001009 1.00006303]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978933 0.99981657 1.00109336 1.00124948 1.00000987 1.00011149]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979327 0.99981033 1.00108689 1.0011683  1.00000965 1.00015731]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979129 0.99983306 1.00084513 1.00080123 1.00000945 1.00017794]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998006  0.99983682 1.00081124 1.00089576 1.00000926 1.00026263]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998235  0.99994352 1.00086744 1.00092992 1.00000908 1.00041623]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99982428 0.9999479  1.00126415 1.00107789 1.00000889 1.00051349]
# Length of chain: 10000

# %% [markdown]
# ---

# %%
linmix_results(N_runs=1, interp=False, type_source=None, names=["4U 1543-47"])
# Out:
# DIRECTORY:  ./MCMC_parfiles_paired_['4U 1543-47']_Nruns_1
# lr0:  4.54e+28
# lx0:  5.47e+35
#
# Source names:  ['4U 1543-47']
# Sources included after filtering:  ['4U 1543-47']
# Number of source: 1
# (10000,) (10000,) (10000,)
#
# USING ALL RESULTS TOGETHER:
# The fitted values and uncertainties based on the mean, 16th, and 84th percentile of all values
# Alpha = 0.714  -0.293  +0.274
# Beta  = 0.947  -0.366  +0.343
# Sigma = 0.764  -0.492  +0.164
# The fitted values and uncertainties based on the median, 16th, and 84th percentile of all values
# Alpha = 0.708  -0.288  +0.280
# Beta  = 0.936  -0.354  +0.355
# Sigma = 0.451  -0.180  +0.477
# The 90% lower limit on beta from all values
# Beta > 0.419
# The 90% upper limit on beta from all values
# Beta < 1.443
#
# USING PERCENTILE RESULTS FROM EACH REPEAT:
# The fitted values based on the mean of the median, 16th, and 84th percentile of the runs
# Alpha =  0.708  -0.288  +0.280
# Beta =  0.936  -0.354  +0.355
# Sigma =  0.451  -0.180  +0.477
# The 90% lower limit on beta from run results
# Beta >  0.42
# The 90% upper limit on beta from run results
# Beta <  1.44

# %% [markdown]
# ---
